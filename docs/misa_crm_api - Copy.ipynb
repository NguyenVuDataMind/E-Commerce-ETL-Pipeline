# %% [markdown]
# # Test MISA CRM API Endpoints
#
# Notebook này dùng để kiểm tra việc lấy dữ liệu từ các API endpoint của MISA CRM.
#
# **Yêu cầu:** Cần điền đầy đủ `MISA_CRM_CLIENT_ID` và `MISA_CRM_CLIENT_SECRET` trong file `.env` trước khi chạy.

# %%
import requests
import os
import json
import pandas as pd
from dotenv import load_dotenv

# Tải các biến môi trường từ file .env
load_dotenv()

# Lấy thông tin từ biến môi trường
MISA_CLIENT_ID = os.getenv('MISA_CRM_CLIENT_ID')
MISA_CLIENT_SECRET = os.getenv('MISA_CRM_CLIENT_SECRET')
BASE_URL = 'https://crmconnect.misa.vn'

print(f"Client ID: {MISA_CLIENT_ID}")
print(f"Client Secret is {'set' if MISA_CLIENT_SECRET else 'not set'}")
# Out:
# Client ID: FACOLOS
# Client Secret is set

# %% [markdown]
# ## 1. Lấy Access Token

# %%
def get_misa_access_token():
    """Hàm để lấy access token từ MISA CRM API."""
    token_url = f"{BASE_URL}/api/v2/Account"
    
    if not MISA_CLIENT_ID or not MISA_CLIENT_SECRET:
        print('Lỗi: Vui lòng điền MISA_CRM_CLIENT_ID và MISA_CRM_CLIENT_SECRET trong file .env')
        return None
    
    payload = {
        'client_id': MISA_CLIENT_ID,
        'client_secret': MISA_CLIENT_SECRET
    }
    headers = {'Content-Type': 'application/json'}
    
    try:
        response = requests.post(token_url, json=payload, headers=headers, timeout=30)
        response.raise_for_status()
        
        result = response.json()
        if result.get('success') and result.get('data'):
            access_token = result['data']
            print('Lấy access token thành công!')
            return access_token
        else:
            print(f"Lấy token thất bại: {result.get('error_message', result)}")
            return None
    except requests.exceptions.RequestException as e:
        print(f'Lỗi kết nối khi lấy token: {e}')
        return None

access_token = get_misa_access_token()
# In một phần token để xác nhận
if access_token:
    print(f'Access Token (Full): {access_token}')
# Out:
# Lấy access token thành công!
# Access Token (Full): eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....bUAY1FT6c8VmhUGqfwRobOgRsRjJx4mWtloBaX5iRyI

# %% [markdown]
# ## 2. Hàm Test Endpoint

# %%
def test_endpoint(endpoint_path, access_token, params=None):
    """Hàm chung để test một endpoint với phân trang."""
    if not access_token:
        print('Không có access token, không thể thực hiện request.')
        return
    
    url = f"{BASE_URL}{endpoint_path}"
    headers = {
        'Authorization': f'Bearer {access_token}',
        'Clientid': MISA_CLIENT_ID
    }
    
    # Mặc định lấy trang đầu tiên, 5 bản ghi
    default_params = {'page': 0, 'pageSize': 5}
    if params:
        default_params.update(params)
    
    print(f'--- Đang gọi đến: {url} với params: {default_params} ---')
    
    try:
        response = requests.get(url, headers=headers, params=default_params, timeout=30)
        response.raise_for_status()
        
        result = response.json()
        print(f'Status Code: {response.status_code}')
        print('Response JSON:')
        print(json.dumps(result, indent=2, ensure_ascii=False))
        
        if result.get('success') and isinstance(result.get('data'), list):
            df = pd.DataFrame(result['data'])
            print('Hiển thị dữ liệu dưới dạng DataFrame:')
            display(df)
        else:
            print('Không có dữ liệu hoặc cấu trúc response không đúng.')
            
    except requests.exceptions.RequestException as e:
        print(f'Lỗi request: {e}')

# %% [markdown]
# ## 3. Test Các Endpoint Cụ Thể

# %%
# Endpoint 2: SaleOrders
test_endpoint('/api/v2/SaleOrders', access_token)
# Out:
# --- Đang gọi đến: https://crmconnect.misa.vn/api/v2/SaleOrders với params: {'page': 0, 'pageSize': 5} ---
# Status Code: 200
# Response JSON:
# {
#   "success": true,
#   "code": 200,
#   "data": [
#     {
#       "id": 3274,
#       "sale_order_no": "DH0003274",
#       "campaign_name": null,
#       "book_date": "2025-07-14T00:00:00.000+07:00",
#       "sale_order_amount": 199375000.03,
#       "deadline_date": null,
#       "quote_name": null,
#       "status": "Đã thực hiện",
#       "exchange_rate": 1.0,
#       "sale_order_name": "Đơn hàng bán cho CÔNG TY TNHH TLT SPORTS",
#       "sale_order_date": "2025-07-14T00:00:00.000+07:00",
#       "account_name": "CÔNG TY TNHH TLT SPORTS",
#       "contact_name": null,
#       "due_date": "2025-07-14T00:00:00.000+07:00",
#       "delivery_status": "Đã giao hàng",
#       "sale_order_type": "Bán mới",
#       "opportunity_name": null,
#       "revenue_status": "Đã ghi",
#       "currency_type": "VND",
#       "description": null,
#       "balance_receipt_amount": 0.03,
#       "pay_status": "Đã thanh toán một phần",
#       "invoiced_amount": 199375000.0,
#       "total_receipted_amount": 199375000.0,
#       "is_invoiced": true,
#       "un_invoiced_amount": 0.03,
#       "paid_date": "2025-07-14T00:00:00.000+07:00",
#       "delivery_date": "2025-07-14T00:00:00.000+07:00",
#       "un_subcrible": false,
#       "billing_account": "CÔNG TY TNHH TLT SPORTS",
#       "billing_country": "Việt Nam",
#       "billing_district": null,
#       "billing_street": "Số 42 ngõ 144 Quan Nhân",
#       "billing_address": "Số 42 Ngõ 144 Quan Nhân, Phường Thanh Xuân, Thành phố Hà Nội, Việt Nam.",
#       "billing_contact": null,
#       "billing_province": "Hà Nội",
#       "billing_ward": "Phường Thanh Xuân",
#       "billing_code": "1011101",
#       "shipping_country": "Việt Nam",
#       "shipping_district": "Quận Đống Đa",
#       "shipping_street": "02 hoàng cầu",
#       "shipping_address": "02 hoàng cầu, Phường Ô Chợ Dừa, Quận Đống Đa, Hà Nội, Việt Nam",
#       "phone": null,
#       "shipping_province": "Hà Nội",
#       "shipping_ward": "Phường Ô Chợ Dừa",
#       "shipping_code": "1010907",
#       "organization_unit_name": "Bộ phận Kinh Doanh",
#       "created_by": "Nguyễn Minh Hiếu (NV06) - CRM",
#       "modified_by": "SME",
#       "form_layout": "Mẫu tiêu chuẩn",
#       "owner_name": "Nguyễn Minh Hiếu (NV06)",
#       "created_date": "2025-07-14T15:11:07.000+07:00",
#       "modified_date": "2025-10-16T11:54:57.000+07:00",
#       "is_public": false,
#       "tag": null,
#       "total_summary": 199375000.03,
#       "tax_summary": 14768518.49,
#       "discount_summary": 151041666.81,
#       "to_currency_summary": 335648148.35,
#       "shipping_amount_summary": 85.0,
#       "sale_order_process_cost": 0.0,
#       "recorded_sale_organization_unit_name": "Bộ phận Kinh Doanh",
#       "recorded_sale_users_name": "Nguyễn Minh Hiếu (NV06)",
#       "parent_name": null,
#       "is_parent_sale_order": null,
#       "liquidate_amount": 199375000.03,
#       "invoice_date": null,
#       "to_currency_summary_oc": 335648148.35,
#       "discount_summary_oc": 151041666.81,
#       "tax_summary_oc": 14768518.49,
#       "total_summary_oc": 199375000.03,
#       "liquidate_amount_oc": 199375000.03,
#       "sale_order_amount_oc": 199375000.03,
#       "total_receipted_amount_oc": 199375000.0,
#       "balance_receipt_amount_oc": 0.03,
#       "invoiced_amount_oc": 199375000.0,
#       "is_use_currency": true,
#       "discount_overall": null,
#       "discount_overall_oc": null,
#       "tax_overall": null,
#       "tax_overall_oc": null,
#       "total_overall": null,
#       "total_overall_oc": null,
#       "discount_percent_overall": null,
#       "tax_percent_overall": null,
#       "to_currency_after_discount_summary": 184606481.54,
#       "to_currency_oc_after_discount_summary": 184606481.54,
#       "shipping_contact_name": "CÔNG TY TNHH TLT SPORTS",
#       "is_correct_route": null,
#       "is_visited": null,
#       "amount_summary": 85.0,
#       "usage_unit_amount_summary": 85.0,
#       "number_of_days_owed": 0,
#       "list_product_category": "PRO,ACCESSORY",
#       "list_product": "BACKPACK-ELITE-WHITE, BACKPACK-ELITE-PINK, BACKPACK-ELITE-NEON, BACKPACK-ELITE-BLUE, PPS-EliteX-14MM-Blue, PPS-EliteX-14MM-Green, PPS-EliteX-16MM-Neon, PPS-EliteX-16MM-Orange, PPS-EliteX-16MM-Green, PPS-EliteX-16MM-Blue, PPS-EliteX-16MM-Pink",
#       "approved_status": null,
#       "approver": null,
#       "approved_date": null,
#       "other_sys_order_code": null,
#       "is_sync_price_after_discount": false,
#       "related_users": null,
#       "promotion_applied": null,
#       "custom_field1Summary": 0.0,
#       "custom_field13": null,
#       "custom_field1": null,
#       "production_confirmation_status": "Chưa gửi",
#       "production_status": null,
#       "production_date": null,
#       "production_rejection_reason": null,
#       "produced_quantity_summary": 0.0,
#       "account_code": "NPPCL01",
#       "contact_code": null,
#       "opportunity_code": null,
#       "quote_code": null,
#       "employee_code": "NV06",
#       "is_deleted": false,
#       "sale_order_product_mappings": [
#         {
#           "id": 12283,
#           "to_currency_oc": 41666666.7,
#           "discount_oc": 18750000.02,
#           "tax_oc": 1833333.33,
#           "total_oc": 24750000.01,
#           "product_code": "PPS-EliteX-16MM-Pink",
#           "unit": "Chiếc",
#           "price": 4166666.67,
#           "amount": 10.0,
#           "to_currency": 41666666.7,
#           "discount": 18750000.02,
#           "tax": 1833333.33,
#           "total": 24750000.01,
#           "tax_percent": "8%",
#           "discount_percent": 45.0,
#           "shipping_amount": 10.0,
#           "stock_name": "FCL_KHO_HN_SI",
#           "description": "Paddles Pro Series - EliteX - 16MM - Pink",
#           "price_after_tax": 0.0,
#           "sort_order": 1,
#           "usage_unit": "Chiếc",
#           "ratio": 1.0,
#           "operator": "Nhân",
#           "usage_unit_amount": 10.0,
#           "usage_unit_price": 4166666.67,
#           "batch_number": null,
#           "exist_amount": null,
#           "height": 0.0,
#           "width": 0.0,
#           "length": 0.0,
#           "radius": 0.0,
#           "mass": 0.0,
#           "price_after_discount": 2291666.67,
#           "to_currency_oc_after_discount": 22916666.68,
#           "to_currency_after_discount": 22916666.68,
#           "promotion": null,
#           "description_product": "Paddles Pro Series - EliteX - 16MM - Pink",
#           "sale_order_product": "",
#           "quantity_ordered": null,
#           "is_promotion": false,
#           "expire_date": null,
#           "serial_number": null,
#           "custom_field1": 0.0,
#           "produced_quantity": 0.0
#         },
#         {
#           "id": 12284,
#           "to_currency_oc": 41666666.7,
#           "discount_oc": 18750000.02,
#           "tax_oc": 1833333.33,
#           "total_oc": 24750000.01,
#           "product_code": "PPS-EliteX-16MM-Blue",
#           "unit": "Chiếc",
#           "price": 4166666.67,
#           "amount": 10.0,
#           "to_currency": 41666666.7,
#           "discount": 18750000.02,
#           "tax": 1833333.33,
#           "total": 24750000.01,
#           "tax_percent": "8%",
#           "discount_percent": 45.0,
#           "shipping_amount": 10.0,
#           "stock_name": "FCL_KHO_HN_SI",
#           "description": "Paddles Pro Series - EliteX - 16MM - Blue",
#           "price_after_tax": 0.0,
#           "sort_order": 2,
#           "usage_unit": "Chiếc",
#           "ratio": 1.0,
#           "operator": "Nhân",
#           "usage_unit_amount": 10.0,
#           "usage_unit_price": 4166666.67,
#           "batch_number": null,
#           "exist_amount": null,
#           "height": 0.0,
#           "width": 0.0,
#           "length": 0.0,
#           "radius": 0.0,
#           "mass": 0.0,
#           "price_after_discount": 2291666.67,
#           "to_currency_oc_after_discount": 22916666.68,
#           "to_currency_after_discount": 22916666.68,
#           "promotion": null,
#           "description_product": "Paddles Pro Series - EliteX - 16MM - Blue",
#           "sale_order_product": null,
#           "quantity_ordered": null,
#           "is_promotion": false,
#           "expire_date": null,
#           "serial_number": null,
#           "custom_field1": 0.0,
#           "produced_quantity": 0.0
#         },
#         {
#           "id": 12285,
#           "to_currency_oc": 20833333.35,
#           "discount_oc": 9375000.01,
#           "tax_oc": 916666.67,
#           "total_oc": 12375000.01,
#           "product_code": "PPS-EliteX-16MM-Green",
#           "unit": "Chiếc",
#           "price": 4166666.67,
#           "amount": 5.0,
#           "to_currency": 20833333.35,
#           "discount": 9375000.01,
#           "tax": 916666.67,
#           "total": 12375000.01,
#           "tax_percent": "8%",
#           "discount_percent": 45.0,
#           "shipping_amount": 5.0,
#           "stock_name": "FCL_KHO_HN_SI",
#           "description": "Paddles Pro Series - EliteX - 16MM - Green",
#           "price_after_tax": 0.0,
#           "sort_order": 3,
#           "usage_unit": "Chiếc",
#           "ratio": 1.0,
#           "operator": "Nhân",
#           "usage_unit_amount": 5.0,
#           "usage_unit_price": 4166666.67,
#           "batch_number": null,
#           "exist_amount": null,
#           "height": 0.0,
#           "width": 0.0,
#           "length": 0.0,
#           "radius": 0.0,
#           "mass": 0.0,
#           "price_after_discount": 2291666.67,
#           "to_currency_oc_after_discount": 11458333.34,
#           "to_currency_after_discount": 11458333.34,
#           "promotion": null,
#           "description_product": "Paddles Pro Series - EliteX - 16MM - Green",
#           "sale_order_product": null,
#           "quantity_ordered": null,
#           "is_promotion": false,
#           "expire_date": null,
#           "serial_number": null,
#           "custom_field1": 0.0,
#           "produced_quantity": 0.0
#         },
#         {
#           "id": 12286,
#           "to_currency_oc": 41666666.7,
#           "discount_oc": 18750000.02,
#           "tax_oc": 1833333.33,
#           "total_oc": 24750000.01,
#           "product_code": "PPS-EliteX-16MM-Orange",
#           "unit": "Chiếc",
#           "price": 4166666.67,
#           "amount": 10.0,
#           "to_currency": 41666666.7,
#           "discount": 18750000.02,
#           "tax": 1833333.33,
#           "total": 24750000.01,
#           "tax_percent": "8%",
#           "discount_percent": 45.0,
#           "shipping_amount": 10.0,
#           "stock_name": "FCL_KHO_HN_SI",
#           "description": "Paddles Pro Series - EliteX - 16MM - Orange",
#           "price_after_tax": 0.0,
#           "sort_order": 4,
#           "usage_unit": "Chiếc",
#           "ratio": 1.0,
#           "operator": "Nhân",
#           "usage_unit_amount": 10.0,
#           "usage_unit_price": 4166666.67,
#           "batch_number": null,
#           "exist_amount": null,
#           "height": 0.0,
#           "width": 0.0,
#           "length": 0.0,
#           "radius": 0.0,
#           "mass": 0.0,
#           "price_after_discount": 2291666.67,
#           "to_currency_oc_after_discount": 22916666.68,
#           "to_currency_after_discount": 22916666.68,
#           "promotion": null,
#           "description_product": "Paddles Pro Series - EliteX - 16MM - Orange",
#           "sale_order_product": null,
#           "quantity_ordered": null,
#           "is_promotion": false,
#           "expire_date": null,
#           "serial_number": null,
#           "custom_field1": 0.0,
#           "produced_quantity": 0.0
#         },
#         {
#           "id": 12287,
#           "to_currency_oc": 41666666.7,
#           "discount_oc": 18750000.02,
#           "tax_oc": 1833333.33,
#           "total_oc": 24750000.01,
#           "product_code": "PPS-EliteX-16MM-Neon",
#           "unit": "Chiếc",
#           "price": 4166666.67,
#           "amount": 10.0,
#           "to_currency": 41666666.7,
#           "discount": 18750000.02,
#           "tax": 1833333.33,
#           "total": 24750000.01,
#           "tax_percent": "8%",
#           "discount_percent": 45.0,
#           "shipping_amount": 10.0,
#           "stock_name": "FCL_KHO_HN_SI",
#           "description": "Paddles Pro Series - EliteX - 16MM - Neon",
#           "price_after_tax": 0.0,
#           "sort_order": 5,
#           "usage_unit": "Chiếc",
#           "ratio": 1.0,
#           "operator": "Nhân",
#           "usage_unit_amount": 10.0,
#           "usage_unit_price": 4166666.67,
#           "batch_number": null,
#           "exist_amount": null,
#           "height": 0.0,
#           "width": 0.0,
#           "length": 0.0,
#           "radius": 0.0,
#           "mass": 0.0,
#           "price_after_discount": 2291666.67,
#           "to_currency_oc_after_discount": 22916666.68,
#           "to_currency_after_discount": 22916666.68,
#           "promotion": null,
#           "description_product": "Paddles Pro Series - EliteX - 16MM - Neon",
#           "sale_order_product": null,
#           "quantity_ordered": null,
#           "is_promotion": false,
#           "expire_date": null,
#           "serial_number": null,
#           "custom_field1": 0.0,
#           "produced_quantity": 0.0
#         },
#         {
#           "id": 12288,
#           "to_currency_oc": 41666666.7,
#           "discount_oc": 18750000.02,
#           "tax_oc": 1833333.33,
#           "total_oc": 24750000.01,
#           "product_code": "PPS-EliteX-14MM-Green",
#           "unit": "Chiếc",
#           "price": 4166666.67,
#           "amount": 10.0,
#           "to_currency": 41666666.7,
#           "discount": 18750000.02,
#           "tax": 1833333.33,
#           "total": 24750000.01,
#           "tax_percent": "8%",
#           "discount_percent": 45.0,
#           "shipping_amount": 10.0,
#           "stock_name": "FCL_KHO_HN_SI",
#           "description": "Paddles Pro Series - EliteX - 14MM - Green",
#           "price_after_tax": 0.0,
#           "sort_order": 6,
#           "usage_unit": "Chiếc",
#           "ratio": 1.0,
#           "operator": "Nhân",
#           "usage_unit_amount": 10.0,
#           "usage_unit_price": 4166666.67,
#           "batch_number": null,
#           "exist_amount": null,
#           "height": 0.0,
#           "width": 0.0,
#           "length": 0.0,
#           "radius": 0.0,
#           "mass": 0.0,
#           "price_after_discount": 2291666.67,
#           "to_currency_oc_after_discount": 22916666.68,
#           "to_currency_after_discount": 22916666.68,
#           "promotion": null,
#           "description_product": "Paddles Pro Series - EliteX - 16MM - Green",
#           "sale_order_product": null,
#           "quantity_ordered": null,
#           "is_promotion": false,
#           "expire_date": null,
#           "serial_number": null,
#           "custom_field1": 0.0,
#           "produced_quantity": 0.0
#         },
#         {
#           "id": 12289,
#           "to_currency_oc": 41666666.7,
#           "discount_oc": 18750000.02,
#           "tax_oc": 1833333.33,
#           "total_oc": 24750000.01,
#           "product_code": "PPS-EliteX-14MM-Blue",
#           "unit": "Chiếc",
#           "price": 4166666.67,
#           "amount": 10.0,
#           "to_currency": 41666666.7,
#           "discount": 18750000.02,
#           "tax": 1833333.33,
#           "total": 24750000.01,
#           "tax_percent": "8%",
#           "discount_percent": 45.0,
#           "shipping_amount": 10.0,
#           "stock_name": "FCL_KHO_HN_SI",
#           "description": "Paddles Pro Series - EliteX - 14MM - Blue",
#           "price_after_tax": 0.0,
#           "sort_order": 7,
#           "usage_unit": "Chiếc",
#           "ratio": 1.0,
#           "operator": "Nhân",
#           "usage_unit_amount": 10.0,
#           "usage_unit_price": 4166666.67,
#           "batch_number": null,
#           "exist_amount": null,
#           "height": 0.0,
#           "width": 0.0,
#           "length": 0.0,
#           "radius": 0.0,
#           "mass": 0.0,
#           "price_after_discount": 2291666.67,
#           "to_currency_oc_after_discount": 22916666.68,
#           "to_currency_after_discount": 22916666.68,
#           "promotion": null,
#           "description_product": "Paddles Pro Series - EliteX - 16MM - Blue",
#           "sale_order_product": null,
#           "quantity_ordered": null,
#           "is_promotion": false,
#           "expire_date": null,
#           "serial_number": null,
#           "custom_field1": 0.0,
#           "produced_quantity": 0.0
#         },
#         {
#           "id": 12290,
#           "to_currency_oc": 16203703.7,
#           "discount_oc": 7291666.67,
#           "tax_oc": 712962.96,
#           "total_oc": 9624999.99,
#           "product_code": "BACKPACK-ELITE-BLUE",
#           "unit": "Chiếc",
#           "price": 3240740.74,
#           "amount": 5.0,
#           "to_currency": 16203703.7,
#           "discount": 7291666.67,
#           "tax": 712962.96,
#           "total": 9624999.99,
#           "tax_percent": "8%",
#           "discount_percent": 45.0,
#           "shipping_amount": 5.0,
#           "stock_name": "FCL_KHO_HN_SI",
#           "description": "Backpack Elite Facolos - Blue",
#           "price_after_tax": 0.0,
#           "sort_order": 8,
#           "usage_unit": "Chiếc",
#           "ratio": 1.0,
#           "operator": "Nhân",
#           "usage_unit_amount": 5.0,
#           "usage_unit_price": 3240740.74,
#           "batch_number": null,
#           "exist_amount": 0.0,
#           "height": 0.0,
#           "width": 0.0,
#           "length": 0.0,
#           "radius": 0.0,
#           "mass": 0.0,
#           "price_after_discount": 1782407.41,
#           "to_currency_oc_after_discount": 8912037.03,
#           "to_currency_after_discount": 8912037.03,
#           "promotion": null,
#           "description_product": "Balo FACOLOS - Blue, Backpack Elite Facolos - Blue",
#           "sale_order_product": null,
#           "quantity_ordered": null,
#           "is_promotion": false,
#           "expire_date": null,
#           "serial_number": null,
#           "custom_field1": 0.0,
#           "produced_quantity": 0.0
#         },
#         {
#           "id": 12291,
#           "to_currency_oc": 16203703.7,
#           "discount_oc": 7291666.67,
#           "tax_oc": 712962.96,
#           "total_oc": 9624999.99,
#           "product_code": "BACKPACK-ELITE-NEON",
#           "unit": "Chiếc",
#           "price": 3240740.74,
#           "amount": 5.0,
#           "to_currency": 16203703.7,
#           "discount": 7291666.67,
#           "tax": 712962.96,
#           "total": 9624999.99,
#           "tax_percent": "8%",
#           "discount_percent": 45.0,
#           "shipping_amount": 5.0,
#           "stock_name": "FCL_KHO_HN_SI",
#           "description": "Backpack Elite Facolos - Neon",
#           "price_after_tax": 0.0,
#           "sort_order": 9,
#           "usage_unit": "Chiếc",
#           "ratio": 1.0,
#           "operator": "Nhân",
#           "usage_unit_amount": 5.0,
#           "usage_unit_price": 3240740.74,
#           "batch_number": null,
#           "exist_amount": 0.0,
#           "height": 0.0,
#           "width": 0.0,
#           "length": 0.0,
#           "radius": 0.0,
#           "mass": 0.0,
#           "price_after_discount": 1782407.41,
#           "to_currency_oc_after_discount": 8912037.03,
#           "to_currency_after_discount": 8912037.03,
#           "promotion": null,
#           "description_product": "Balo FACOLOS - Neon Balo thể thao đựng vợt Pickleball, Blue, Phiên bản Elite, nhãn hiệu Facolos",
#           "sale_order_product": null,
#           "quantity_ordered": null,
#           "is_promotion": false,
#           "expire_date": null,
#           "serial_number": null,
#           "custom_field1": 0.0,
#           "produced_quantity": 0.0
#         },
#         {
#           "id": 12292,
#           "to_currency_oc": 16203703.7,
#           "discount_oc": 7291666.67,
#           "tax_oc": 712962.96,
#           "total_oc": 9624999.99,
#           "product_code": "BACKPACK-ELITE-PINK",
#           "unit": "Chiếc",
#           "price": 3240740.74,
#           "amount": 5.0,
#           "to_currency": 16203703.7,
#           "discount": 7291666.67,
#           "tax": 712962.96,
#           "total": 9624999.99,
#           "tax_percent": "8%",
#           "discount_percent": 45.0,
#           "shipping_amount": 5.0,
#           "stock_name": "FCL_KHO_HN_SI",
#           "description": "Backpack Elite Facolos - Pink",
#           "price_after_tax": 0.0,
#           "sort_order": 10,
#           "usage_unit": "Chiếc",
#           "ratio": 1.0,
#           "operator": "Nhân",
#           "usage_unit_amount": 5.0,
#           "usage_unit_price": 3240740.74,
#           "batch_number": null,
#           "exist_amount": 0.0,
#           "height": 0.0,
#           "width": 0.0,
#           "length": 0.0,
#           "radius": 0.0,
#           "mass": 0.0,
#           "price_after_discount": 1782407.41,
#           "to_currency_oc_after_discount": 8912037.03,
#           "to_currency_after_discount": 8912037.03,
#           "promotion": null,
#           "description_product": "Balo FACOLOS - Pink",
#           "sale_order_product": null,
#           "quantity_ordered": null,
#           "is_promotion": false,
#           "expire_date": null,
#           "serial_number": null,
#           "custom_field1": 0.0,
#           "produced_quantity": 0.0
#         },
#         {
#           "id": 12293,
#           "to_currency_oc": 16203703.7,
#           "discount_oc": 7291666.67,
#           "tax_oc": 712962.96,
#           "total_oc": 9624999.99,
#           "product_code": "BACKPACK-ELITE-WHITE",
#           "unit": "Chiếc",
#           "price": 3240740.74,
#           "amount": 5.0,
#           "to_currency": 16203703.7,
#           "discount": 7291666.67,
#           "tax": 712962.96,
#           "total": 9624999.99,
#           "tax_percent": "8%",
#           "discount_percent": 45.0,
#           "shipping_amount": 5.0,
#           "stock_name": "FCL_KHO_HN_SI",
#           "description": "Backpack Elite Facolos - White",
#           "price_after_tax": 0.0,
#           "sort_order": 11,
#           "usage_unit": "Chiếc",
#           "ratio": 1.0,
#           "operator": "Nhân",
#           "usage_unit_amount": 5.0,
#           "usage_unit_price": 3240740.74,
#           "batch_number": null,
#           "exist_amount": 0.0,
#           "height": 0.0,
#           "width": 0.0,
#           "length": 0.0,
#           "radius": 0.0,
#           "mass": 0.0,
#           "price_after_discount": 1782407.41,
#           "to_currency_oc_after_discount": 8912037.03,
#           "to_currency_after_discount": 8912037.03,
#           "promotion": null,
#           "description_product": "Balo FACOLOS - White",
#           "sale_order_product": null,
#           "quantity_ordered": null,
#           "is_promotion": false,
#           "expire_date": null,
#           "serial_number": null,
#           "custom_field1": 0.0,
#           "produced_quantity": 0.0
#         }
#       ]
#     },
#     {
#       "id": 3256,
#       "sale_order_no": "DH0003256",
#       "campaign_name": null,
#       "book_date": "2025-07-13T00:00:00.000+07:00",
#       "sale_order_amount": 94050007.53,
#       "deadline_date": null,
#       "quote_name": null,
#       "status": "Đang thực hiện",
#       "exchange_rate": 1.0,
#       "sale_order_name": "Đơn hàng bán cho HỘ KINH DOANH T&D PICKAPOO",
#       "sale_order_date": "2025-07-13T00:00:00.000+07:00",
#       "account_name": "HỘ KINH DOANH T&D PICKAPOO",
#       "contact_name": null,
#       "due_date": "2025-07-13T00:00:00.000+07:00",
#       "delivery_status": "Đã giao hàng",
#       "sale_order_type": "Bán mới",
#       "opportunity_name": null,
#       "revenue_status": "Đã ghi",
#       "currency_type": "VND",
#       "description": null,
#       "balance_receipt_amount": 667.53,
#       "pay_status": "Đã thanh toán một phần",
#       "invoiced_amount": 94050000.0,
#       "total_receipted_amount": 94049340.0,
#       "is_invoiced": true,
#       "un_invoiced_amount": 7.53,
#       "paid_date": "2025-07-13T00:00:00.000+07:00",
#       "delivery_date": "2025-07-14T00:00:00.000+07:00",
#       "un_subcrible": false,
#       "billing_account": "HỘ KINH DOANH T&D PICKAPOO",
#       "billing_country": "Việt Nam",
#       "billing_district": null,
#       "billing_street": "Lô Đất A6, Tập Thể Viện Hoá, Số 21 Trần Quốc Hoàn, Phường Cầu Giấy",
#       "billing_address": "Lô Đất A6, Tập Thể Viện Hoá, Số 21 Trần Quốc Hoàn, Phường Cầu Giấy, Hà Nội, Việt Nam",
#       "billing_contact": null,
#       "billing_province": "Hà Nội",
#       "billing_ward": null,
#       "billing_code": null,
#       "shipping_country": "Việt Nam",
#       "shipping_district": "Quận Cầu Giấy",
#       "shipping_street": "21 Trần Quốc Hoàn",
#       "shipping_address": "21 Trần Quốc Hoàn, Phường Dịch Vọng Hậu, Quận Cầu Giấy, Hà Nội, Việt Nam",
#       "phone": "0395217812",
#       "shipping_province": "Hà Nội",
#       "shipping_ward": "Phường Dịch Vọng Hậu",
#       "shipping_code": null,
#       "organization_unit_name": "Bộ phận Kinh doanh Miền Bắc",
#       "created_by": "Nguyên Thế Hưng (NV13) - CRM",
#       "modified_by": "SME",
#       "form_layout": "Mẫu tiêu chuẩn",
#       "owner_name": "Nguyên Thế Hưng (NV13)",
#       "created_date": "2025-07-13T14:39:41.000+07:00",
#       "modified_date": "2025-10-16T11:54:07.000+07:00",
#       "is_public": false,
#       "tag": null,
#       "total_summary": 94050007.53,
#       "tax_summary": 6966667.23,
#       "discount_summary": 71250005.7,
#       "to_currency_summary": 158333346.0,
#       "shipping_amount_summary": 38.0,
#       "sale_order_process_cost": null,
#       "recorded_sale_organization_unit_name": "Bộ phận Kinh doanh Miền Bắc",
#       "recorded_sale_users_name": "Nguyên Thế Hưng (NV13)",
#       "parent_name": null,
#       "is_parent_sale_order": null,
#       "liquidate_amount": 94050007.53,
#       "invoice_date": null,
#       "to_currency_summary_oc": 158333346.0,
#       "discount_summary_oc": 71250005.7,
#       "tax_summary_oc": 6966667.23,
#       "total_summary_oc": 94050007.53,
#       "liquidate_amount_oc": 94050007.53,
#       "sale_order_amount_oc": 94050007.53,
#       "total_receipted_amount_oc": 94049340.0,
#       "balance_receipt_amount_oc": 667.53,
#       "invoiced_amount_oc": 94050000.0,
#       "is_use_currency": false,
#       "discount_overall": null,
#       "discount_overall_oc": null,
#       "tax_overall": null,
#       "tax_overall_oc": null,
#       "total_overall": null,
#       "total_overall_oc": null,
#       "discount_percent_overall": null,
#       "tax_percent_overall": null,
#       "to_currency_after_discount_summary": 87083340.3,
#       "to_currency_oc_after_discount_summary": 87083340.3,
#       "shipping_contact_name": "HỘ KINH DOANH T&D PICKAPOO",
#       "is_correct_route": false,
#       "is_visited": false,
#       "amount_summary": 38.0,
#       "usage_unit_amount_summary": 38.0,
#       "number_of_days_owed": 0,
#       "list_product_category": "PRO",
#       "list_product": "PPS-EliteX-14MM-Pink, PPS-EliteX-14MM-Neon, PPS-EliteX-14MM-Blue, PPS-EliteX-16MM-Pink, PPS-EliteX-16MM-Orange, PPS-EliteX-16MM-Neon, PPS-EliteX-16MM-Blue",
#       "approved_status": null,
#       "approver": null,
#       "approved_date": null,
#       "other_sys_order_code": null,
#       "is_sync_price_after_discount": false,
#       "related_users": null,
#       "promotion_applied": "KM0000008",
#       "custom_field1Summary": 0.0,
#       "custom_field13": null,
#       "custom_field1": null,
#       "production_confirmation_status": "Chưa gửi",
#       "production_status": null,
#       "production_date": null,
#       "production_rejection_reason": null,
#       "produced_quantity_summary": 0.0,
#       "account_code": "NPP05",
#       "contact_code": null,
#       "opportunity_code": null,
#       "quote_code": null,
#       "employee_code": "NV13",
#       "is_deleted": false,
#       "sale_order_product_mappings": [
#         {
#           "id": 12210,
#           "to_currency_oc": 50000004.0,
#           "discount_oc": 22500001.8,
#           "tax_oc": 2200000.18,
#           "total_oc": 29700002.38,
#           "product_code": "PPS-EliteX-16MM-Blue",
#           "unit": "Chiếc",
#           "price": 4166667.0,
#           "amount": 12.0,
#           "to_currency": 50000004.0,
#           "discount": 22500001.8,
#           "tax": 2200000.18,
#           "total": 29700002.38,
#           "tax_percent": "8%",
#           "discount_percent": 45.0,
#           "shipping_amount": 12.0,
#           "stock_name": "FCL_KHO_HN_SI",
#           "description": "Paddles Pro Series - EliteX - 16MM - Blue",
#           "price_after_tax": 0.0,
#           "sort_order": 1,
#           "usage_unit": "Chiếc",
#           "ratio": 1.0,
#           "operator": "Nhân",
#           "usage_unit_amount": 12.0,
#           "usage_unit_price": 4166667.0,
#           "batch_number": null,
#           "exist_amount": 0.0,
#           "height": 0.0,
#           "width": 0.0,
#           "length": 0.0,
#           "radius": 0.0,
#           "mass": 0.0,
#           "price_after_discount": 2291666.85,
#           "to_currency_oc_after_discount": 27500002.2,
#           "to_currency_after_discount": 27500002.2,
#           "promotion": "KM0000008",
#           "description_product": "Paddles Pro Series - EliteX - 16MM - Blue",
#           "sale_order_product": null,
#           "quantity_ordered": null,
#           "is_promotion": false,
#           "expire_date": null,
#           "serial_number": null,
#           "custom_field1": 0.0,
#           "produced_quantity": null
#         },
#         {
#           "id": 12211,
#           "to_currency_oc": 29166669.0,
#           "discount_oc": 13125001.05,
#           "tax_oc": 1283333.44,
#           "total_oc": 17325001.39,
#           "product_code": "PPS-EliteX-16MM-Neon",
#           "unit": "Chiếc",
#           "price": 4166667.0,
#           "amount": 7.0,
#           "to_currency": 29166669.0,
#           "discount": 13125001.05,
#           "tax": 1283333.44,
#           "total": 17325001.39,
#           "tax_percent": "8%",
#           "discount_percent": 45.0,
#           "shipping_amount": 7.0,
#           "stock_name": "FCL_KHO_HN_SI",
#           "description": "Paddles Pro Series - EliteX - 16MM - Neon",
#           "price_after_tax": 0.0,
#           "sort_order": 2,
#           "usage_unit": "Chiếc",
#           "ratio": 1.0,
#           "operator": "Nhân",
#           "usage_unit_amount": 7.0,
#           "usage_unit_price": 4166667.0,
#           "batch_number": null,
#           "exist_amount": 0.0,
#           "height": 0.0,
#           "width": 0.0,
#           "length": 0.0,
#           "radius": 0.0,
#           "mass": 0.0,
#           "price_after_discount": 2291666.85,
#           "to_currency_oc_after_discount": 16041667.95,
#           "to_currency_after_discount": 16041667.95,
#           "promotion": "KM0000008",
#           "description_product": "Paddles Pro Series - EliteX - 16MM - Neon",
#           "sale_order_product": null,
#           "quantity_ordered": null,
#           "is_promotion": false,
#           "expire_date": null,
#           "serial_number": null,
#           "custom_field1": 0.0,
#           "produced_quantity": null
#         },
#         {
#           "id": 12212,
#           "to_currency_oc": 12500001.0,
#           "discount_oc": 5625000.45,
#           "tax_oc": 550000.04,
#           "total_oc": 7425000.59,
#           "product_code": "PPS-EliteX-16MM-Orange",
#           "unit": "Chiếc",
#           "price": 4166667.0,
#           "amount": 3.0,
#           "to_currency": 12500001.0,
#           "discount": 5625000.45,
#           "tax": 550000.04,
#           "total": 7425000.59,
#           "tax_percent": "8%",
#           "discount_percent": 45.0,
#           "shipping_amount": 3.0,
#           "stock_name": "FCL_KHO_HN_SI",
#           "description": "Paddles Pro Series - EliteX - 16MM - Orange",
#           "price_after_tax": 0.0,
#           "sort_order": 3,
#           "usage_unit": "Chiếc",
#           "ratio": 1.0,
#           "operator": "Nhân",
#           "usage_unit_amount": 3.0,
#           "usage_unit_price": 4166667.0,
#           "batch_number": null,
#           "exist_amount": 0.0,
#           "height": 0.0,
#           "width": 0.0,
#           "length": 0.0,
#           "radius": 0.0,
#           "mass": 0.0,
#           "price_after_discount": 2291666.85,
#           "to_currency_oc_after_discount": 6875000.55,
#           "to_currency_after_discount": 6875000.55,
#           "promotion": "KM0000008",
#           "description_product": "Paddles Pro Series - EliteX - 16MM - Orange",
#           "sale_order_product": null,
#           "quantity_ordered": null,
#           "is_promotion": false,
#           "expire_date": null,
#           "serial_number": null,
#           "custom_field1": 0.0,
#           "produced_quantity": null
#         },
#         {
#           "id": 12213,
#           "to_currency_oc": 16666668.0,
#           "discount_oc": 7500000.6,
#           "tax_oc": 733333.39,
#           "total_oc": 9900000.79,
#           "product_code": "PPS-EliteX-16MM-Pink",
#           "unit": "Chiếc",
#           "price": 4166667.0,
#           "amount": 4.0,
#           "to_currency": 16666668.0,
#           "discount": 7500000.6,
#           "tax": 733333.39,
#           "total": 9900000.79,
#           "tax_percent": "8%",
#           "discount_percent": 45.0,
#           "shipping_amount": 4.0,
#           "stock_name": "FCL_KHO_HN_SI",
#           "description": "Paddles Pro Series - EliteX - 16MM - Pink",
#           "price_after_tax": 0.0,
#           "sort_order": 4,
#           "usage_unit": "Chiếc",
#           "ratio": 1.0,
#           "operator": "Nhân",
#           "usage_unit_amount": 4.0,
#           "usage_unit_price": 4166667.0,
#           "batch_number": null,
#           "exist_amount": 0.0,
#           "height": 0.0,
#           "width": 0.0,
#           "length": 0.0,
#           "radius": 0.0,
#           "mass": 0.0,
#           "price_after_discount": 2291666.85,
#           "to_currency_oc_after_discount": 9166667.4,
#           "to_currency_after_discount": 9166667.4,
#           "promotion": "KM0000008",
#           "description_product": "Paddles Pro Series - EliteX - 16MM - Pink",
#           "sale_order_product": null,
#           "quantity_ordered": null,
#           "is_promotion": false,
#           "expire_date": null,
#           "serial_number": null,
#           "custom_field1": 0.0,
#           "produced_quantity": null
#         },
#         {
#           "id": 12214,
#           "to_currency_oc": 20833335.0,
#           "discount_oc": 9375000.75,
#           "tax_oc": 916666.74,
#           "total_oc": 12375000.99,
#           "product_code": "PPS-EliteX-14MM-Blue",
#           "unit": "Chiếc",
#           "price": 4166667.0,
#           "amount": 5.0,
#           "to_currency": 20833335.0,
#           "discount": 9375000.75,
#           "tax": 916666.74,
#           "total": 12375000.99,
#           "tax_percent": "8%",
#           "discount_percent": 45.0,
#           "shipping_amount": 5.0,
#           "stock_name": "FCL_KHO_HN_SI",
#           "description": "Paddles Pro Series - EliteX - 14MM - Blue",
#           "price_after_tax": 0.0,
#           "sort_order": 5,
#           "usage_unit": "Chiếc",
#           "ratio": 1.0,
#           "operator": "Nhân",
#           "usage_unit_amount": 5.0,
#           "usage_unit_price": 4166667.0,
#           "batch_number": null,
#           "exist_amount": 0.0,
#           "height": 0.0,
#           "width": 0.0,
#           "length": 0.0,
#           "radius": 0.0,
#           "mass": 0.0,
#           "price_after_discount": 2291666.85,
#           "to_currency_oc_after_discount": 11458334.25,
#           "to_currency_after_discount": 11458334.25,
#           "promotion": "KM0000008",
#           "description_product": "Paddles Pro Series - EliteX - 16MM - Blue",
#           "sale_order_product": null,
#           "quantity_ordered": null,
#           "is_promotion": false,
#           "expire_date": null,
#           "serial_number": null,
#           "custom_field1": 0.0,
#           "produced_quantity": null
#         },
#         {
#           "id": 12215,
#           "to_currency_oc": 8333334.0,
#           "discount_oc": 3750000.3,
#           "tax_oc": 366666.7,
#           "total_oc": 4950000.4,
#           "product_code": "PPS-EliteX-14MM-Neon",
#           "unit": "Chiếc",
#           "price": 4166667.0,
#           "amount": 2.0,
#           "to_currency": 8333334.0,
#           "discount": 3750000.3,
#           "tax": 366666.7,
#           "total": 4950000.4,
#           "tax_percent": "8%",
#           "discount_percent": 45.0,
#           "shipping_amount": 2.0,
#           "stock_name": "FCL_KHO_HN_SI",
#           "description": "Paddles Pro Series - EliteX - 14MM - Neon",
#           "price_after_tax": 0.0,
#           "sort_order": 6,
#           "usage_unit": "Chiếc",
#           "ratio": 1.0,
#           "operator": "Nhân",
#           "usage_unit_amount": 2.0,
#           "usage_unit_price": 4166667.0,
#           "batch_number": null,
#           "exist_amount": 0.0,
#           "height": 0.0,
#           "width": 0.0,
#           "length": 0.0,
#           "radius": 0.0,
#           "mass": 0.0,
#           "price_after_discount": 2291666.85,
#           "to_currency_oc_after_discount": 4583333.7,
#           "to_currency_after_discount": 4583333.7,
#           "promotion": "KM0000008",
#           "description_product": "Paddles Pro Series - EliteX - 14MM - Neon",
#           "sale_order_product": null,
#           "quantity_ordered": null,
#           "is_promotion": false,
#           "expire_date": null,
#           "serial_number": null,
#           "custom_field1": 0.0,
#           "produced_quantity": null
#         },
#         {
#           "id": 12216,
#           "to_currency_oc": 20833335.0,
#           "discount_oc": 9375000.75,
#           "tax_oc": 916666.74,
#           "total_oc": 12375000.99,
#           "product_code": "PPS-EliteX-14MM-Pink",
#           "unit": "Chiếc",
#           "price": 4166667.0,
#           "amount": 5.0,
#           "to_currency": 20833335.0,
#           "discount": 9375000.75,
#           "tax": 916666.74,
#           "total": 12375000.99,
#           "tax_percent": "8%",
#           "discount_percent": 45.0,
#           "shipping_amount": 5.0,
#           "stock_name": "FCL_KHO_HN_SI",
#           "description": "Paddles Pro Series - EliteX - 14MM - Pink",
#           "price_after_tax": 0.0,
#           "sort_order": 7,
#           "usage_unit": "Chiếc",
#           "ratio": 1.0,
#           "operator": "Nhân",
#           "usage_unit_amount": 5.0,
#           "usage_unit_price": 4166667.0,
#           "batch_number": null,
#           "exist_amount": 0.0,
#           "height": 0.0,
#           "width": 0.0,
#           "length": 0.0,
#           "radius": 0.0,
#           "mass": 0.0,
#           "price_after_discount": 2291666.85,
#           "to_currency_oc_after_discount": 11458334.25,
#           "to_currency_after_discount": 11458334.25,
#           "promotion": "KM0000008",
#           "description_product": "Paddles Pro Series - EliteX - 14MM - Pink",
#           "sale_order_product": null,
#           "quantity_ordered": null,
#           "is_promotion": false,
#           "expire_date": null,
#           "serial_number": null,
#           "custom_field1": 0.0,
#           "produced_quantity": null
#         }
#       ]
#     },
#     {
#       "id": 3218,
#       "sale_order_no": "DH0003218",
#       "campaign_name": null,
#       "book_date": "2025-07-12T00:00:00.000+07:00",
#       "sale_order_amount": 72765001.52,
#       "deadline_date": null,
#       "quote_name": null,
#       "status": "Đã thực hiện",
#       "exchange_rate": 1.0,
#       "sale_order_name": "Đơn hàng bán cho CÔNG TY TNHH ĐẦU TƯ THƯƠNG MẠI XUẤT NHẬP KHẨU HOÀNG TUẤN",
#       "sale_order_date": "2025-07-10T00:00:00.000+07:00",
#       "account_name": "CÔNG TY TNHH ĐẦU TƯ THƯƠNG MẠI XUẤT NHẬP KHẨU HOÀNG TUẤN",
#       "contact_name": null,
#       "due_date": "2025-07-10T00:00:00.000+07:00",
#       "delivery_status": "Đã giao hàng",
#       "sale_order_type": "Bán mới",
#       "opportunity_name": null,
#       "revenue_status": "Đã ghi",
#       "currency_type": "VND",
#       "description": null,
#       "balance_receipt_amount": 1.52,
#       "pay_status": "Đã thanh toán một phần",
#       "invoiced_amount": 72765000.0,
#       "total_receipted_amount": 72765000.0,
#       "is_invoiced": true,
#       "un_invoiced_amount": 1.52,
#       "paid_date": "2025-07-12T00:00:00.000+07:00",
#       "delivery_date": "2025-07-12T00:00:00.000+07:00",
#       "un_subcrible": false,
#       "billing_account": "CÔNG TY TNHH ĐẦU TƯ THƯƠNG MẠI XUẤT NHẬP KHẨU HOÀNG TUẤN",
#       "billing_country": "Việt Nam",
#       "billing_district": null,
#       "billing_street": "434 đường Thăng Long",
#       "billing_address": "434 đường Thăng Long, Phường Cẩm Lệ, Thành phố Đà Nẵng, Việt Nam.",
#       "billing_contact": null,
#       "billing_province": "Đà Nẵng",
#       "billing_ward": "Phường Cẩm Lệ",
#       "billing_code": null,
#       "shipping_country": "Việt Nam",
#       "shipping_district": "Quận Hải Châu",
#       "shipping_street": "Văn phòng Hoàng Tuấn, 267 Hoàng Diệu, Hải Châu, Đà nẵng",
#       "shipping_address": "Văn phòng Hoàng Tuấn, 267 Hoàng Diệu, Hải Châu, Đà nẵng Quận Hải Châu, Đà Nẵng",
#       "phone": "090 5423335",
#       "shipping_province": "ĐÀ NẴNG",
#       "shipping_ward": null,
#       "shipping_code": "50101",
#       "organization_unit_name": "Bộ phận Kinh doanh Miền Trung",
#       "created_by": "Nguyễn Dương Long (NV09) - CRM",
#       "modified_by": "SME",
#       "form_layout": "Mẫu tiêu chuẩn",
#       "owner_name": "Nguyễn Dương Long (NV09)",
#       "created_date": "2025-07-10T17:07:09.000+07:00",
#       "modified_date": "2025-10-16T11:53:40.000+07:00",
#       "is_public": false,
#       "tag": null,
#       "total_summary": 72765001.52,
#       "tax_summary": 5390000.12,
#       "discount_summary": 55125001.134,
#       "to_currency_summary": 122500002.52,
#       "shipping_amount_summary": 363.0,
#       "sale_order_process_cost": null,
#       "recorded_sale_organization_unit_name": "Bộ phận Kinh doanh Miền Trung",
#       "recorded_sale_users_name": "Nguyễn Dương Long (NV09)",
#       "parent_name": null,
#       "is_parent_sale_order": false,
#       "liquidate_amount": 72765001.52,
#       "invoice_date": null,
#       "to_currency_summary_oc": 122500002.52,
#       "discount_summary_oc": 55125001.134,
#       "tax_summary_oc": 5390000.12,
#       "total_summary_oc": 72765001.52,
#       "liquidate_amount_oc": 72765001.52,
#       "sale_order_amount_oc": 72765001.52,
#       "total_receipted_amount_oc": 72765000.0,
#       "balance_receipt_amount_oc": 1.52,
#       "invoiced_amount_oc": 72765000.0,
#       "is_use_currency": false,
#       "discount_overall": null,
#       "discount_overall_oc": null,
#       "tax_overall": null,
#       "tax_overall_oc": null,
#       "total_overall": null,
#       "total_overall_oc": null,
#       "discount_percent_overall": null,
#       "tax_percent_overall": null,
#       "to_currency_after_discount_summary": 67375001.4,
#       "to_currency_oc_after_discount_summary": 67375001.4,
#       "shipping_contact_name": "CÔNG TY TNHH ĐẦU TƯ THƯƠNG MẠI XUẤT NHẬP KHẨU HOÀNG TUẤN",
#       "is_correct_route": false,
#       "is_visited": false,
#       "amount_summary": 363.0,
#       "usage_unit_amount_summary": 363.0,
#       "number_of_days_owed": 0,
#       "list_product_category": "BALLS,PRO",
#       "list_product": "PPS-EliteX-16MM-Pink, PPS-EliteX-16MM-Orange, PPS-EliteX-16MM-Neon, PPS-EliteX-16MM-Blue, BOX3BALLSG2, BOX150BALLSG2",
#       "approved_status": null,
#       "approver": null,
#       "approved_date": null,
#       "other_sys_order_code": null,
#       "is_sync_price_after_discount": false,
#       "related_users": null,
#       "promotion_applied": "KM0000008",
#       "custom_field1Summary": 0.0,
#       "custom_field13": null,
#       "custom_field1": null,
#       "production_confirmation_status": "Chưa gửi",
#       "production_status": null,
#       "production_date": null,
#       "production_rejection_reason": null,
#       "produced_quantity_summary": 0.0,
#       "account_code": "NPP03",
#       "contact_code": null,
#       "opportunity_code": null,
#       "quote_code": null,
#       "employee_code": "NV09",
#       "is_deleted": false,
#       "sale_order_product_mappings": [
#         {
#           "id": 11964,
#           "to_currency_oc": 22500000.0,
#           "discount_oc": 10125000.0,
#           "tax_oc": 990000.0,
#           "total_oc": 13365000.0,
#           "product_code": "BOX150BALLSG2",
#           "unit": "Thùng",
#           "price": 7500000.0,
#           "amount": 3.0,
#           "to_currency": 22500000.0,
#           "discount": 10125000.0,
#           "tax": 990000.0,
#           "total": 13365000.0,
#           "tax_percent": "8%",
#           "discount_percent": 45.0,
#           "shipping_amount": 3.0,
#           "stock_name": "FCL_KHO_HN_SI",
#           "description": "F-Pro Performance Pickleball Gen2 ( Box 150 Balls )",
#           "price_after_tax": 0.0,
#           "sort_order": 1,
#           "usage_unit": "Thùng",
#           "ratio": 1.0,
#           "operator": "Nhân",
#           "usage_unit_amount": 3.0,
#           "usage_unit_price": 7500000.0,
#           "batch_number": null,
#           "exist_amount": 0.0,
#           "height": 0.0,
#           "width": 0.0,
#           "length": 0.0,
#           "radius": 0.0,
#           "mass": 0.0,
#           "price_after_discount": 4125000.0,
#           "to_currency_oc_after_discount": 12375000.0,
#           "to_currency_after_discount": 12375000.0,
#           "promotion": "KM0000008",
#           "description_product": "F-Pro Performance Pickleball Gen2 ( Box 150 Balls )",
#           "sale_order_product": null,
#           "quantity_ordered": null,
#           "is_promotion": false,
#           "expire_date": null,
#           "serial_number": null,
#           "custom_field1": 0.0,
#           "produced_quantity": null
#         },
#         {
#           "id": 11965,
#           "to_currency_oc": 58333334.5,
#           "discount_oc": 26250000.53,
#           "tax_oc": 2566666.72,
#           "total_oc": 34650000.7,
#           "product_code": "BOX3BALLSG2",
#           "unit": "Hộp",
#           "price": 166666.67,
#           "amount": 350.0,
#           "to_currency": 58333334.5,
#           "discount": 26250000.525,
#           "tax": 2566666.72,
#           "total": 34650000.7,
#           "tax_percent": "8%",
#           "discount_percent": 45.0,
#           "shipping_amount": 350.0,
#           "stock_name": "FCL_KHO_HN_SI",
#           "description": "F-Pro Performance Pickleball Gen2 ( Box 3 Balls )",
#           "price_after_tax": 0.0,
#           "sort_order": 2,
#           "usage_unit": "Hộp",
#           "ratio": 1.0,
#           "operator": "Nhân",
#           "usage_unit_amount": 350.0,
#           "usage_unit_price": 166666.67,
#           "batch_number": null,
#           "exist_amount": 0.0,
#           "height": 0.0,
#           "width": 0.0,
#           "length": 0.0,
#           "radius": 0.0,
#           "mass": 0.0,
#           "price_after_discount": 91666.67,
#           "to_currency_oc_after_discount": 32083333.98,
#           "to_currency_after_discount": 32083333.98,
#           "promotion": "KM0000008",
#           "description_product": "F-Pro Performance Pickleball Gen2 ( Box 3 Balls )",
#           "sale_order_product": null,
#           "quantity_ordered": null,
#           "is_promotion": false,
#           "expire_date": null,
#           "serial_number": null,
#           "custom_field1": 0.0,
#           "produced_quantity": null
#         },
#         {
#           "id": 12116,
#           "to_currency_oc": 8333333.34,
#           "discount_oc": 3750000.0,
#           "tax_oc": 366666.67,
#           "total_oc": 4950000.01,
#           "product_code": "PPS-EliteX-16MM-Blue",
#           "unit": "Chiếc",
#           "price": 4166666.67,
#           "amount": 2.0,
#           "to_currency": 8333333.34,
#           "discount": 3750000.003,
#           "tax": 366666.67,
#           "total": 4950000.01,
#           "tax_percent": "8%",
#           "discount_percent": 45.0,
#           "shipping_amount": 2.0,
#           "stock_name": "FCL_KHO_HN_SI",
#           "description": "Paddles Pro Series - EliteX - 16MM - Blue",
#           "price_after_tax": 0.0,
#           "sort_order": 3,
#           "usage_unit": "Chiếc",
#           "ratio": 1.0,
#           "operator": "Nhân",
#           "usage_unit_amount": 2.0,
#           "usage_unit_price": 4166666.67,
#           "batch_number": null,
#           "exist_amount": 0.0,
#           "height": 0.0,
#           "width": 0.0,
#           "length": 0.0,
#           "radius": 0.0,
#           "mass": 0.0,
#           "price_after_discount": 2291666.67,
#           "to_currency_oc_after_discount": 4583333.34,
#           "to_currency_after_discount": 4583333.34,
#           "promotion": "KM0000008",
#           "description_product": "Paddles Pro Series - EliteX - 16MM - Blue",
#           "sale_order_product": null,
#           "quantity_ordered": null,
#           "is_promotion": false,
#           "expire_date": null,
#           "serial_number": null,
#           "custom_field1": 0.0,
#           "produced_quantity": null
#         },
#         {
#           "id": 12117,
#           "to_currency_oc": 8333333.34,
#           "discount_oc": 3750000.0,
#           "tax_oc": 366666.67,
#           "total_oc": 4950000.01,
# ...
#       "is_invoiced": true,
#       "un_invoiced_amount": -3.95,
#       "paid_date": "2025-07-11T00:00:00.000+07:00",
#       "delivery_date": "2025-07-11T00:00:00.000+07:00",
#       "un_subcrible": null,
#       "billing_account": "JP SPORT - 01",
#       "billing_country": "Việt Nam",
#       "billing_district": "Quận Thanh Xuân",
#       "billing_street": "618 nguyễn trãi",
#       "billing_address": "618 nguyễn trãi, Phường Thanh Xuân Bắc, Quận Thanh Xuân, Hà Nội, Việt Nam",
#       "billing_contact": null,
#       "billing_province": "Hà Nội",
#       "billing_ward": "Phường Thanh Xuân Bắc",
#       "billing_code": "1011121",
#       "shipping_country": "Việt Nam",
#       "shipping_district": "Quận Thanh Xuân",
#       "shipping_street": "618 nguyễn trãi",
#       "shipping_address": "618 nguyễn trãi, Phường Thanh Xuân Bắc, Quận Thanh Xuân, Hà Nội, Việt Nam",
#       "phone": "0964873789",
#       "shipping_province": "Hà Nội",
#       "shipping_ward": "Phường Thanh Xuân Bắc",
#       "shipping_code": "1011121",
#       "organization_unit_name": "Bộ phận Kinh doanh Miền Bắc",
#       "created_by": "Đoàn Đức Trung (DOANTRUNG) - CRM",
#       "modified_by": "SME",
#       "form_layout": "Mẫu tiêu chuẩn",
#       "owner_name": "Đoàn Đức Trung (DOANTRUNG)",
#       "created_date": "2025-07-11T16:16:34.000+07:00",
#       "modified_date": "2025-10-16T11:53:05.000+07:00",
#       "is_public": false,
#       "tag": null,
#       "total_summary": 51975000.05,
#       "tax_summary": 3850000.01,
#       "discount_summary": 39375000.03,
#       "to_currency_summary": 87500000.07,
#       "shipping_amount_summary": 21.0,
#       "sale_order_process_cost": 0.0,
#       "recorded_sale_organization_unit_name": "Bộ phận Kinh doanh Miền Bắc",
#       "recorded_sale_users_name": "Đoàn Đức Trung (DOANTRUNG)",
#       "parent_name": null,
#       "is_parent_sale_order": null,
#       "liquidate_amount": 51975000.05,
#       "invoice_date": null,
#       "to_currency_summary_oc": 87500000.07,
#       "discount_summary_oc": 39375000.03,
#       "tax_summary_oc": 3850000.01,
#       "total_summary_oc": 51975000.05,
#       "liquidate_amount_oc": 51975000.05,
#       "sale_order_amount_oc": 51975000.05,
#       "total_receipted_amount_oc": 51975004.0,
#       "balance_receipt_amount_oc": -3.95,
#       "invoiced_amount_oc": 51975004.0,
#       "is_use_currency": false,
#       "discount_overall": null,
#       "discount_overall_oc": null,
#       "tax_overall": null,
#       "tax_overall_oc": null,
#       "total_overall": null,
#       "total_overall_oc": null,
#       "discount_percent_overall": 0.0,
#       "tax_percent_overall": null,
#       "to_currency_after_discount_summary": 48125000.04,
#       "to_currency_oc_after_discount_summary": 48125000.04,
#       "shipping_contact_name": "JP Sport - 01",
#       "is_correct_route": null,
#       "is_visited": null,
#       "amount_summary": 21.0,
#       "usage_unit_amount_summary": 21.0,
#       "number_of_days_owed": 0,
#       "list_product_category": "PRO",
#       "list_product": "PPS-EliteX-14MM-Orange, PPS-EliteX-14MM-Green, PPS-EliteX-16MM-Orange, PPS-EliteX-16MM-Neon, PPS-EliteX-16MM-Green, PPS-EliteX-16MM-Blue",
#       "approved_status": null,
#       "approver": null,
#       "approved_date": null,
#       "other_sys_order_code": null,
#       "is_sync_price_after_discount": false,
#       "related_users": null,
#       "promotion_applied": "KM0000008",
#       "custom_field1Summary": 0.0,
#       "custom_field13": null,
#       "custom_field1": null,
#       "production_confirmation_status": "Chưa gửi",
#       "production_status": null,
#       "production_date": null,
#       "production_rejection_reason": null,
#       "produced_quantity_summary": 0.0,
#       "account_code": "NPP19 - 02",
#       "contact_code": null,
#       "opportunity_code": null,
#       "quote_code": null,
#       "employee_code": "DOANTRUNG",
#       "is_deleted": false,
#       "sale_order_product_mappings": [
#         {
#           "id": 12138,
#           "to_currency_oc": 25000000.02,
#           "discount_oc": 11250000.01,
#           "tax_oc": 1100000.0,
#           "total_oc": 14850000.01,
#           "product_code": "PPS-EliteX-16MM-Blue",
#           "unit": "Chiếc",
#           "price": 4166666.67,
#           "amount": 6.0,
#           "to_currency": 25000000.02,
#           "discount": 11250000.01,
#           "tax": 1100000.0,
#           "total": 14850000.01,
#           "tax_percent": "8%",
#           "discount_percent": 45.0,
#           "shipping_amount": 6.0,
#           "stock_name": "FCL_KHO_HN_SI",
#           "description": "Paddles Pro Series - EliteX - 16MM - Blue",
#           "price_after_tax": 0.0,
#           "sort_order": 1,
#           "usage_unit": "Chiếc",
#           "ratio": 1.0,
#           "operator": "Nhân",
#           "usage_unit_amount": 6.0,
#           "usage_unit_price": 4166666.67,
#           "batch_number": null,
#           "exist_amount": null,
#           "height": 0.0,
#           "width": 0.0,
#           "length": 0.0,
#           "radius": 0.0,
#           "mass": 0.0,
#           "price_after_discount": 2291666.67,
#           "to_currency_oc_after_discount": 13750000.01,
#           "to_currency_after_discount": 13750000.01,
#           "promotion": "KM0000008",
#           "description_product": "Paddles Pro Series - EliteX - 16MM - Blue",
#           "sale_order_product": null,
#           "quantity_ordered": null,
#           "is_promotion": false,
#           "expire_date": null,
#           "serial_number": null,
#           "custom_field1": 0.0,
#           "produced_quantity": 0.0
#         },
#         {
#           "id": 12139,
#           "to_currency_oc": 8333333.34,
#           "discount_oc": 3750000.0,
#           "tax_oc": 366666.67,
#           "total_oc": 4950000.01,
#           "product_code": "PPS-EliteX-16MM-Green",
#           "unit": "Chiếc",
#           "price": 4166666.67,
#           "amount": 2.0,
#           "to_currency": 8333333.34,
#           "discount": 3750000.0,
#           "tax": 366666.67,
#           "total": 4950000.01,
#           "tax_percent": "8%",
#           "discount_percent": 45.0,
#           "shipping_amount": 2.0,
#           "stock_name": "FCL_KHO_HN_SI",
#           "description": "Paddles Pro Series - EliteX - 16MM - Green",
#           "price_after_tax": 0.0,
#           "sort_order": 2,
#           "usage_unit": "Chiếc",
#           "ratio": 1.0,
#           "operator": "Nhân",
#           "usage_unit_amount": 2.0,
#           "usage_unit_price": 4166666.67,
#           "batch_number": null,
#           "exist_amount": null,
#           "height": 0.0,
#           "width": 0.0,
#           "length": 0.0,
#           "radius": 0.0,
#           "mass": 0.0,
#           "price_after_discount": 2291666.67,
#           "to_currency_oc_after_discount": 4583333.34,
#           "to_currency_after_discount": 4583333.34,
#           "promotion": "KM0000008",
#           "description_product": "Paddles Pro Series - EliteX - 16MM - Green",
#           "sale_order_product": null,
#           "quantity_ordered": null,
#           "is_promotion": false,
#           "expire_date": null,
#           "serial_number": null,
#           "custom_field1": 0.0,
#           "produced_quantity": 0.0
#         },
#         {
#           "id": 12140,
#           "to_currency_oc": 16666666.68,
#           "discount_oc": 7500000.01,
#           "tax_oc": 733333.33,
#           "total_oc": 9900000.0,
#           "product_code": "PPS-EliteX-16MM-Neon",
#           "unit": "Chiếc",
#           "price": 4166666.67,
#           "amount": 4.0,
#           "to_currency": 16666666.68,
#           "discount": 7500000.01,
#           "tax": 733333.33,
#           "total": 9900000.0,
#           "tax_percent": "8%",
#           "discount_percent": 45.0,
#           "shipping_amount": 4.0,
#           "stock_name": "FCL_KHO_HN_SI",
#           "description": "Paddles Pro Series - EliteX - 16MM - Neon",
#           "price_after_tax": 0.0,
#           "sort_order": 3,
#           "usage_unit": "Chiếc",
#           "ratio": 1.0,
#           "operator": "Nhân",
#           "usage_unit_amount": 4.0,
#           "usage_unit_price": 4166666.67,
#           "batch_number": null,
#           "exist_amount": null,
#           "height": 0.0,
#           "width": 0.0,
#           "length": 0.0,
#           "radius": 0.0,
#           "mass": 0.0,
#           "price_after_discount": 2291666.67,
#           "to_currency_oc_after_discount": 9166666.67,
#           "to_currency_after_discount": 9166666.67,
#           "promotion": "KM0000008",
#           "description_product": "Paddles Pro Series - EliteX - 16MM - Neon",
#           "sale_order_product": null,
#           "quantity_ordered": null,
#           "is_promotion": false,
#           "expire_date": null,
#           "serial_number": null,
#           "custom_field1": 0.0,
#           "produced_quantity": 0.0
#         },
#         {
#           "id": 12141,
#           "to_currency_oc": 20833333.35,
#           "discount_oc": 9375000.01,
#           "tax_oc": 916666.67,
#           "total_oc": 12375000.01,
#           "product_code": "PPS-EliteX-16MM-Orange",
#           "unit": "Chiếc",
#           "price": 4166666.67,
#           "amount": 5.0,
#           "to_currency": 20833333.35,
#           "discount": 9375000.01,
#           "tax": 916666.67,
#           "total": 12375000.01,
#           "tax_percent": "8%",
#           "discount_percent": 45.0,
#           "shipping_amount": 5.0,
#           "stock_name": "FCL_KHO_HN_SI",
#           "description": "Paddles Pro Series - EliteX - 16MM - Orange",
#           "price_after_tax": 0.0,
#           "sort_order": 4,
#           "usage_unit": "Chiếc",
#           "ratio": 1.0,
#           "operator": "Nhân",
#           "usage_unit_amount": 5.0,
#           "usage_unit_price": 4166666.67,
#           "batch_number": null,
#           "exist_amount": null,
#           "height": 0.0,
#           "width": 0.0,
#           "length": 0.0,
#           "radius": 0.0,
#           "mass": 0.0,
#           "price_after_discount": 2291666.67,
#           "to_currency_oc_after_discount": 11458333.34,
#           "to_currency_after_discount": 11458333.34,
#           "promotion": "KM0000008",
#           "description_product": "Paddles Pro Series - EliteX - 16MM - Orange",
#           "sale_order_product": null,
#           "quantity_ordered": null,
#           "is_promotion": false,
#           "expire_date": null,
#           "serial_number": null,
#           "custom_field1": 0.0,
#           "produced_quantity": 0.0
#         },
#         {
#           "id": 12142,
#           "to_currency_oc": 8333333.34,
#           "discount_oc": 3750000.0,
#           "tax_oc": 366666.67,
#           "total_oc": 4950000.01,
#           "product_code": "PPS-EliteX-14MM-Green",
#           "unit": "Chiếc",
#           "price": 4166666.67,
#           "amount": 2.0,
#           "to_currency": 8333333.34,
#           "discount": 3750000.0,
#           "tax": 366666.67,
#           "total": 4950000.01,
#           "tax_percent": "8%",
#           "discount_percent": 45.0,
#           "shipping_amount": 2.0,
#           "stock_name": "FCL_KHO_HN_SI",
#           "description": "Paddles Pro Series - EliteX - 14MM - Green",
#           "price_after_tax": 0.0,
#           "sort_order": 5,
#           "usage_unit": "Chiếc",
#           "ratio": 1.0,
#           "operator": "Nhân",
#           "usage_unit_amount": 2.0,
#           "usage_unit_price": 4166666.67,
#           "batch_number": null,
#           "exist_amount": null,
#           "height": 0.0,
#           "width": 0.0,
#           "length": 0.0,
#           "radius": 0.0,
#           "mass": 0.0,
#           "price_after_discount": 2291666.67,
#           "to_currency_oc_after_discount": 4583333.34,
#           "to_currency_after_discount": 4583333.34,
#           "promotion": "KM0000008",
#           "description_product": "Paddles Pro Series - EliteX - 16MM - Green",
#           "sale_order_product": null,
#           "quantity_ordered": null,
#           "is_promotion": false,
#           "expire_date": null,
#           "serial_number": null,
#           "custom_field1": 0.0,
#           "produced_quantity": 0.0
#         },
#         {
#           "id": 12143,
#           "to_currency_oc": 8333333.34,
#           "discount_oc": 3750000.0,
#           "tax_oc": 366666.67,
#           "total_oc": 4950000.01,
#           "product_code": "PPS-EliteX-14MM-Orange",
#           "unit": "Chiếc",
#           "price": 4166666.67,
#           "amount": 2.0,
#           "to_currency": 8333333.34,
#           "discount": 3750000.0,
#           "tax": 366666.67,
#           "total": 4950000.01,
#           "tax_percent": "8%",
#           "discount_percent": 45.0,
#           "shipping_amount": 2.0,
#           "stock_name": "FCL_KHO_HN_SI",
#           "description": "Paddles Pro Series - EliteX - 14MM - Orange",
#           "price_after_tax": 0.0,
#           "sort_order": 6,
#           "usage_unit": "Chiếc",
#           "ratio": 1.0,
#           "operator": "Nhân",
#           "usage_unit_amount": 2.0,
#           "usage_unit_price": 4166666.67,
#           "batch_number": null,
#           "exist_amount": null,
#           "height": 0.0,
#           "width": 0.0,
#           "length": 0.0,
#           "radius": 0.0,
#           "mass": 0.0,
#           "price_after_discount": 2291666.67,
#           "to_currency_oc_after_discount": 4583333.34,
#           "to_currency_after_discount": 4583333.34,
#           "promotion": "KM0000008",
#           "description_product": "Paddles Pro Series - EliteX - 14MM - Orange",
#           "sale_order_product": null,
#           "quantity_ordered": null,
#           "is_promotion": false,
#           "expire_date": null,
#           "serial_number": null,
#           "custom_field1": 0.0,
#           "produced_quantity": 0.0
#         }
#       ]
#     }
#   ]
# }
# Hiển thị dữ liệu dưới dạng DataFrame:
#      id sale_order_no campaign_name                      book_date  \
# 0  3274     DH0003274          None  2025-07-14T00:00:00.000+07:00
# 1  3256     DH0003256          None  2025-07-13T00:00:00.000+07:00
# 2  3218     DH0003218          None  2025-07-12T00:00:00.000+07:00
# 3  5871   DH101020808          None  2025-10-15T00:00:00.000+07:00
# 4  3236     DH0003236          None  2025-07-11T00:00:00.000+07:00
#
#    sale_order_amount deadline_date quote_name          status  exchange_rate  \
# 0       1.993750e+08          None       None    Đã thực hiện            1.0
# 1       9.405001e+07          None       None  Đang thực hiện            1.0
# 2       7.276500e+07          None       None    Đã thực hiện            1.0
# 3       2.700000e+05          None       None  Đang thực hiện            1.0
# 4       5.197500e+07          None       None    Đã thực hiện            1.0
#
#                                      sale_order_name  ... production_date  \
# 0           Đơn hàng bán cho CÔNG TY TNHH TLT SPORTS  ...            None
# 1        Đơn hàng bán cho HỘ KINH DOANH T&D PICKAPOO  ...            None
# 2  Đơn hàng bán cho CÔNG TY TNHH ĐẦU TƯ THƯƠNG MẠ...  ...            None
# 3  Đơn hàng tặng cho Lê Đàm Huy trúng giải mini game  ...            None
# 4                     Đơn hàng bán cho JP Sport - 01  ...            None
#
#   production_rejection_reason produced_quantity_summary account_code  \
# 0                        None                       0.0      NPPCL01
# 1                        None                       0.0        NPP05
# 2                        None                       0.0        NPP03
# 3                        None                       0.0   KH20092228
# 4                        None                       0.0   NPP19 - 02
#
#   contact_code opportunity_code quote_code employee_code is_deleted  \
# 0         None             None       None          NV06      False
# 1         None             None       None          NV13      False
# 2         None             None       None          NV09      False
# 3         None             None       None       XUANDAO      False
# 4         None             None       None     DOANTRUNG      False
#
#                          sale_order_product_mappings
# 0  [{'id': 12283, 'to_currency_oc': 41666666.7, '...
# 1  [{'id': 12210, 'to_currency_oc': 50000004.0, '...
# 2  [{'id': 11964, 'to_currency_oc': 22500000.0, '...
# 3  [{'id': 22059, 'to_currency_oc': 250000.0, 'di...
# 4  [{'id': 12138, 'to_currency_oc': 25000000.02, ...
#
# [5 rows x 117 columns]

# %%
# Lấy dữ liệu SaleOrders cho ngày 14 và 15 tháng 10 năm 2025
from datetime import datetime, timezone
import pandas as pd

def get_sale_orders_by_date_range(access_token, start_date, end_date, page_size=100):
    """
    Lấy dữ liệu SaleOrders theo khoảng thời gian
    
    Args:
        access_token: Token xác thực
        start_date: Ngày bắt đầu (YYYY-MM-DD)
        end_date: Ngày kết thúc (YYYY-MM-DD)
        page_size: Số bản ghi mỗi trang
    """
    if not access_token:
        print('Không có access token, không thể thực hiện request.')
        return []
    
    url = f"{BASE_URL}/api/v2/SaleOrders"
    headers = {
        'Authorization': f'Bearer {access_token}',
        'Clientid': MISA_CLIENT_ID,
        'Content-Type': 'application/json'
    }
    
    all_orders = []
    page = 0
    
    print(f"Đang lấy dữ liệu SaleOrders từ {start_date} đến {end_date}...")
    
    while True:
        params = {
            'page': page,
            'pageSize': page_size
        }
        
        try:
            response = requests.get(url, headers=headers, params=params, timeout=30)
            response.raise_for_status()
            
            result = response.json()
            
            if not result.get('success') or not isinstance(result.get('data'), list):
                print(f"Lỗi response: {result}")
                break
                
            orders = result['data']
            if not orders:
                print(f"Không còn dữ liệu ở trang {page}")
                break
            
            # Lọc theo ngày
            filtered_orders = []
            for order in orders:
                sale_order_date = order.get('sale_order_date', '')
                if sale_order_date:
                    # Parse ngày từ format ISO
                    try:
                        order_date = pd.to_datetime(sale_order_date).date()
                        start_dt = datetime.strptime(start_date, '%Y-%m-%d').date()
                        end_dt = datetime.strptime(end_date, '%Y-%m-%d').date()
                        
                        if start_dt <= order_date <= end_dt:
                            filtered_orders.append(order)
                    except Exception as e:
                        print(f"Lỗi parse ngày {sale_order_date}: {e}")
                        continue
            
            all_orders.extend(filtered_orders)
            print(f"Trang {page}: Lấy {len(orders)} orders, lọc được {len(filtered_orders)} orders trong khoảng thời gian")
            
            # Nếu số orders ít hơn page_size, đây là trang cuối
            if len(orders) < page_size:
                break
                
            page += 1
            
        except requests.exceptions.RequestException as e:
            print(f'Lỗi request trang {page}: {e}')
            break
        except Exception as e:
            print(f'Lỗi không xác định trang {page}: {e}')
            break
    
    print(f"Tổng cộng lấy được {len(all_orders)} orders trong khoảng thời gian {start_date} đến {end_date}")
    return all_orders

# Lấy dữ liệu cho ngày 14 và 15 tháng 10 năm 2025
orders_oct_14_15 = get_sale_orders_by_date_range(
    access_token=access_token,
    start_date='2025-10-14',
    end_date='2025-10-15',
    page_size=100
)

print(f"\n=== KẾT QUẢ ===")
print(f"Số lượng orders: {len(orders_oct_14_15)}")

if orders_oct_14_15:
    # Hiển thị thông tin chi tiết các orders
    for i, order in enumerate(orders_oct_14_15[:5]):  # Chỉ hiển thị 5 orders đầu
        print(f"\n--- Order {i+1} ---")
        print(f"Số đơn hàng: {order.get('sale_order_no', 'N/A')}")
        print(f"Tên đơn hàng: {order.get('sale_order_name', 'N/A')}")
        print(f"Ngày đơn hàng: {order.get('sale_order_date', 'N/A')}")
        print(f"Ngày đến hạn: {order.get('due_date', 'N/A')}")
        print(f"Khách hàng: {order.get('account_name', 'N/A')}")
        print(f"Trạng thái: {order.get('status', 'N/A')}")
        print(f"Tổng tiền: {order.get('total_summary', 'N/A')}")
        print(f"Ngày tạo: {order.get('created_date', 'N/A')}")
        print(f"Ngày sửa: {order.get('modified_date', 'N/A')}")
    
    if len(orders_oct_14_15) > 5:
        print(f"\n... và {len(orders_oct_14_15) - 5} orders khác")
    
    # Tạo DataFrame để phân tích
    df_orders = pd.DataFrame(orders_oct_14_15)
    
    # Hiển thị các cột datetime quan trọng
    datetime_cols = ['sale_order_date', 'due_date', 'created_date', 'modified_date']
    available_datetime_cols = [col for col in datetime_cols if col in df_orders.columns]
    
    if available_datetime_cols:
        print(f"\n=== PHÂN TÍCH CÁC TRƯỜNG THỜI GIAN ===")
        for col in available_datetime_cols:
            print(f"\nCột {col}:")
            print(f"  - Số giá trị không null: {df_orders[col].notna().sum()}")
            print(f"  - Các giá trị mẫu:")
            sample_values = df_orders[col].dropna().head(3).tolist()
            for val in sample_values:
                print(f"    + {val}")
else:
    print("Không tìm thấy orders nào trong khoảng thời gian này")
# Out:
# Đang lấy dữ liệu SaleOrders từ 2025-10-14 đến 2025-10-15...
# Trang 0: Lấy 100 orders, lọc được 21 orders trong khoảng thời gian
# Trang 1: Lấy 100 orders, lọc được 40 orders trong khoảng thời gian
# Trang 2: Lấy 100 orders, lọc được 32 orders trong khoảng thời gian
# Trang 3: Lấy 100 orders, lọc được 4 orders trong khoảng thời gian
# Trang 4: Lấy 100 orders, lọc được 3 orders trong khoảng thời gian
# Trang 5: Lấy 100 orders, lọc được 7 orders trong khoảng thời gian
# Trang 6: Lấy 100 orders, lọc được 3 orders trong khoảng thời gian
# Trang 7: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 8: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 9: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 10: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 11: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 12: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 13: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 14: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 15: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 16: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 17: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 18: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 19: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 20: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 21: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 22: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 23: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 24: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 25: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 26: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 27: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 28: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 29: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 30: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 31: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 32: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 33: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 34: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 35: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 36: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 37: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 38: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 39: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 40: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 41: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 42: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 43: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 44: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 45: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 46: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 47: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 48: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 49: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 50: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 51: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 52: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 53: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 54: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 55: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 56: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 57: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 58: Lấy 23 orders, lọc được 0 orders trong khoảng thời gian
# Tổng cộng lấy được 110 orders trong khoảng thời gian 2025-10-14 đến 2025-10-15
#
# === KẾT QUẢ ===
# Số lượng orders: 110
#
# --- Order 1 ---
# Số đơn hàng: DH101020808
# Tên đơn hàng: Đơn hàng tặng cho Lê Đàm Huy trúng giải mini game
# Ngày đơn hàng: 2025-10-15T00:00:00.000+07:00
# Ngày đến hạn: 2025-10-15T00:00:00.000+07:00
# Khách hàng: Lê Đàm Huy
# Trạng thái: Đang thực hiện
# Tổng tiền: 270000.0
# Ngày tạo: 2025-10-15T13:40:53.000+07:00
# Ngày sửa: 2025-10-16T11:53:12.000+07:00
#
# --- Order 2 ---
# Số đơn hàng: DH101020782
# Tên đơn hàng: Đơn bán + đơn ctrinh cồng dồn tặng bóng DH101020655 - 10 c, DH101020713 - 1c, DH101020732 - 1c, DH101020691 - 1c, DH101020782 - 7c
# Ngày đơn hàng: 2025-10-15T00:00:00.000+07:00
# Ngày đến hạn: 2025-10-15T00:00:00.000+07:00
# Khách hàng: Nguyễn Minh Hiếu
# Trạng thái: Đã thực hiện
# Tổng tiền: 20781370.0
# Ngày tạo: 2025-10-15T10:35:15.000+07:00
# Ngày sửa: 2025-10-16T11:52:20.000+07:00
#
# --- Order 3 ---
# Số đơn hàng: DH101020828
# Tên đơn hàng: Đơn hàng tặng cho KOL/CELEB
# Ngày đơn hàng: 2025-10-15T00:00:00.000+07:00
# Ngày đến hạn: 2025-10-15T00:00:00.000+07:00
# Khách hàng: Nguyễn Huỳnh Như
# Trạng thái: Đang thực hiện
# Tổng tiền: 3350000.0
# Ngày tạo: 2025-10-15T16:58:15.000+07:00
# Ngày sửa: 2025-10-16T11:49:35.000+07:00
#
# --- Order 4 ---
# Số đơn hàng: DH101020812
# Tên đơn hàng: Đơn hàng tặng cho Trịnh Thị Tuyết Mai trúng giải mini game
# Ngày đơn hàng: 2025-10-15T00:00:00.000+07:00
# Ngày đến hạn: 2025-10-15T00:00:00.000+07:00
# Khách hàng: Trịnh Thị Tuyết Mai
# Trạng thái: Đang thực hiện
# Tổng tiền: 540000.0
# Ngày tạo: 2025-10-15T14:14:10.000+07:00
# Ngày sửa: 2025-10-16T11:46:06.000+07:00
#
# --- Order 5 ---
# Số đơn hàng: DH101020819
# Tên đơn hàng: Đơn hàng tặng cho Pham Ngoc Hoi trúng mini game
# Ngày đơn hàng: 2025-10-15T00:00:00.000+07:00
# Ngày đến hạn: 2025-10-15T00:00:00.000+07:00
# Khách hàng: Pham Ngoc Hoi
# Trạng thái: Đang thực hiện
# Tổng tiền: 540000.0
# Ngày tạo: 2025-10-15T14:39:15.000+07:00
# Ngày sửa: 2025-10-16T11:45:03.000+07:00
#
# ... và 105 orders khác
#
# === PHÂN TÍCH CÁC TRƯỜNG THỜI GIAN ===
#
# Cột sale_order_date:
#   - Số giá trị không null: 110
#   - Các giá trị mẫu:
#     + 2025-10-15T00:00:00.000+07:00
#     + 2025-10-15T00:00:00.000+07:00
#     + 2025-10-15T00:00:00.000+07:00
#
# Cột due_date:
#   - Số giá trị không null: 110
#   - Các giá trị mẫu:
#     + 2025-10-15T00:00:00.000+07:00
#     + 2025-10-15T00:00:00.000+07:00
#     + 2025-10-15T00:00:00.000+07:00
#
# Cột created_date:
#   - Số giá trị không null: 110
#   - Các giá trị mẫu:
#     + 2025-10-15T13:40:53.000+07:00
#     + 2025-10-15T10:35:15.000+07:00
#     + 2025-10-15T16:58:15.000+07:00
#
# Cột modified_date:
#   - Số giá trị không null: 110
#   - Các giá trị mẫu:
#     + 2025-10-16T11:53:12.000+07:00
#     + 2025-10-16T11:52:20.000+07:00
#     + 2025-10-16T11:49:35.000+07:00

# %%
# Test xử lý datetime để kiểm tra logic timezone
if orders_oct_14_15:
    print("=== TEST XỬ LÝ DATETIME ===")
    
    # Lấy một order mẫu để test
    sample_order = orders_oct_14_15[0]
    
    print(f"Order mẫu: {sample_order.get('sale_order_no', 'N/A')}")
    print(f"Ngày đơn hàng gốc: {sample_order.get('sale_order_date', 'N/A')}")
    print(f"Ngày đến hạn gốc: {sample_order.get('due_date', 'N/A')}")
    
    # Test xử lý datetime theo 2 cách
    sale_order_date_raw = sample_order.get('sale_order_date', '')
    due_date_raw = sample_order.get('due_date', '')
    
    if sale_order_date_raw:
        print(f"\n--- XỬ LÝ SALE_ORDER_DATE ---")
        print(f"Dữ liệu gốc: {sale_order_date_raw}")
        
        # Cách 1: Xử lý SAI (như hiện tại trong sale_orders)
        try:
            wrong_way = pd.to_datetime(sale_order_date_raw, errors="coerce")
            print(f"Cách SAI (không utc=True): {wrong_way}")
            print(f"Timezone: {wrong_way.tzinfo}")
        except Exception as e:
            print(f"Lỗi cách SAI: {e}")
        
        # Cách 2: Xử lý ĐÚNG (như customers/contacts)
        try:
            correct_way_utc = pd.to_datetime(sale_order_date_raw, utc=True, errors="coerce")
            print(f"Cách ĐÚNG (utc=True): {correct_way_utc}")
            print(f"Timezone: {correct_way_utc.tzinfo}")
            
            # Chuyển về timezone-naive
            correct_way_naive = correct_way_utc.tz_convert(None)
            print(f"Sau khi tz_convert(None): {correct_way_naive}")
            print(f"Timezone: {correct_way_naive.tzinfo}")
        except Exception as e:
            print(f"Lỗi cách ĐÚNG: {e}")
    
    if due_date_raw:
        print(f"\n--- XỬ LÝ DUE_DATE ---")
        print(f"Dữ liệu gốc: {due_date_raw}")
        
        # Cách 1: Xử lý SAI
        try:
            wrong_way = pd.to_datetime(due_date_raw, errors="coerce")
            print(f"Cách SAI (không utc=True): {wrong_way}")
            print(f"Timezone: {wrong_way.tzinfo}")
        except Exception as e:
            print(f"Lỗi cách SAI: {e}")
        
        # Cách 2: Xử lý ĐÚNG
        try:
            correct_way_utc = pd.to_datetime(due_date_raw, utc=True, errors="coerce")
            print(f"Cách ĐÚNG (utc=True): {correct_way_utc}")
            print(f"Timezone: {correct_way_utc.tzinfo}")
            
            # Chuyển về timezone-naive
            correct_way_naive = correct_way_utc.tz_convert(None)
            print(f"Sau khi tz_convert(None): {correct_way_naive}")
            print(f"Timezone: {correct_way_naive.tzinfo}")
        except Exception as e:
            print(f"Lỗi cách ĐÚNG: {e}")
    
    print(f"\n=== KẾT LUẬN ===")
    print("1. Dữ liệu gốc từ MISA CRM có timezone +07:00 (giờ Việt Nam)")
    print("2. Xử lý SAI: Giữ nguyên timezone +07:00, hiển thị sai thời gian UTC")
    print("3. Xử lý ĐÚNG: Chuyển từ +07:00 về UTC, hiển thị đúng thời gian UTC")
    print("4. Chênh lệch: 7 giờ (tương đương 1 ngày trong một số trường hợp)")
else:
    print("Không có dữ liệu để test")
# Out:
# === TEST XỬ LÝ DATETIME ===
# Order mẫu: DH101020808
# Ngày đơn hàng gốc: 2025-10-15T00:00:00.000+07:00
# Ngày đến hạn gốc: 2025-10-15T00:00:00.000+07:00
#
# --- XỬ LÝ SALE_ORDER_DATE ---
# Dữ liệu gốc: 2025-10-15T00:00:00.000+07:00
# Cách SAI (không utc=True): 2025-10-15 00:00:00+07:00
# Timezone: UTC+07:00
# Cách ĐÚNG (utc=True): 2025-10-14 17:00:00+00:00
# Timezone: UTC
# Sau khi tz_convert(None): 2025-10-14 17:00:00
# Timezone: None
#
# --- XỬ LÝ DUE_DATE ---
# Dữ liệu gốc: 2025-10-15T00:00:00.000+07:00
# Cách SAI (không utc=True): 2025-10-15 00:00:00+07:00
# Timezone: UTC+07:00
# Cách ĐÚNG (utc=True): 2025-10-14 17:00:00+00:00
# Timezone: UTC
# Sau khi tz_convert(None): 2025-10-14 17:00:00
# Timezone: None
#
# === KẾT LUẬN ===
# 1. Dữ liệu gốc từ MISA CRM có timezone +07:00 (giờ Việt Nam)
# 2. Xử lý SAI: Giữ nguyên timezone +07:00, hiển thị sai thời gian UTC
# 3. Xử lý ĐÚNG: Chuyển từ +07:00 về UTC, hiển thị đúng thời gian UTC
# 4. Chênh lệch: 7 giờ (tương đương 1 ngày trong một số trường hợp)

# %%
# Lấy dữ liệu JSON thô của SaleOrders cho ngày 14 và 15 tháng 10 năm 2025
import json

def get_sale_orders_json_by_date_range(access_token, start_date, end_date, page_size=100):
    """
    Lấy dữ liệu JSON thô của SaleOrders theo khoảng thời gian
    """
    if not access_token:
        print('Không có access token, không thể thực hiện request.')
        return []
    
    url = f"{BASE_URL}/api/v2/SaleOrders"
    headers = {
        'Authorization': f'Bearer {access_token}',
        'Clientid': MISA_CLIENT_ID,
        'Content-Type': 'application/json'
    }
    
    all_orders = []
    page = 0
    
    print(f"Đang lấy dữ liệu JSON SaleOrders từ {start_date} đến {end_date}...")
    
    while True:
        params = {
            'page': page,
            'pageSize': page_size
        }
        
        try:
            response = requests.get(url, headers=headers, params=params, timeout=30)
            response.raise_for_status()
            
            result = response.json()
            
            if not result.get('success') or not isinstance(result.get('data'), list):
                print(f"Lỗi response: {result}")
                break
                
            orders = result['data']
            if not orders:
                print(f"Không còn dữ liệu ở trang {page}")
                break
            
            # Lọc theo ngày (chỉ kiểm tra ngày, không parse datetime)
            filtered_orders = []
            for order in orders:
                sale_order_date = order.get('sale_order_date', '')
                if sale_order_date:
                    # Kiểm tra ngày bằng string matching
                    if start_date in sale_order_date or end_date in sale_order_date:
                        filtered_orders.append(order)
            
            all_orders.extend(filtered_orders)
            print(f"Trang {page}: Lấy {len(orders)} orders, lọc được {len(filtered_orders)} orders trong khoảng thời gian")
            
            # Nếu số orders ít hơn page_size, đây là trang cuối
            if len(orders) < page_size:
                break
                
            page += 1
            
        except requests.exceptions.RequestException as e:
            print(f'Lỗi request trang {page}: {e}')
            break
        except Exception as e:
            print(f'Lỗi không xác định trang {page}: {e}')
            break
    
    print(f"Tổng cộng lấy được {len(all_orders)} orders trong khoảng thời gian {start_date} đến {end_date}")
    return all_orders

# Lấy dữ liệu JSON thô cho ngày 14 và 15 tháng 10 năm 2025
orders_oct_14_15_json = get_sale_orders_json_by_date_range(
    access_token=access_token,
    start_date='2025-10-14',
    end_date='2025-10-15',
    page_size=100
)

print(f"\n=== DỮ LIỆU JSON THÔ ===")
print(f"Số lượng orders: {len(orders_oct_14_15_json)}")

if orders_oct_14_15_json:
    # Hiển thị JSON đầy đủ của từng order
    for i, order in enumerate(orders_oct_14_15_json):
        print(f"\n{'='*50}")
        print(f"ORDER {i+1} - JSON ĐẦY ĐỦ:")
        print(f"{'='*50}")
        print(json.dumps(order, indent=2, ensure_ascii=False))
        
        # Chỉ hiển thị tối đa 3 orders để tránh quá dài
        if i >= 2:
            print(f"\n... và {len(orders_oct_14_15_json) - 3} orders khác")
            break
else:
    print("Không tìm thấy orders nào trong khoảng thời gian này")
# Out:
# Đang lấy dữ liệu JSON SaleOrders từ 2025-10-14 đến 2025-10-15...
# Trang 0: Lấy 100 orders, lọc được 21 orders trong khoảng thời gian
# Trang 1: Lấy 100 orders, lọc được 39 orders trong khoảng thời gian
# Trang 2: Lấy 100 orders, lọc được 33 orders trong khoảng thời gian
# Trang 3: Lấy 100 orders, lọc được 4 orders trong khoảng thời gian
# Trang 4: Lấy 100 orders, lọc được 3 orders trong khoảng thời gian
# Trang 5: Lấy 100 orders, lọc được 7 orders trong khoảng thời gian
# Trang 6: Lấy 100 orders, lọc được 3 orders trong khoảng thời gian
# Trang 7: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 8: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 9: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 10: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 11: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 12: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 13: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 14: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 15: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 16: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 17: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 18: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 19: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 20: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 21: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 22: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 23: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 24: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 25: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 26: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 27: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 28: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 29: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 30: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 31: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 32: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 33: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 34: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 35: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 36: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 37: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 38: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 39: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 40: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 41: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 42: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 43: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 44: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 45: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 46: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 47: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 48: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 49: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 50: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 51: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 52: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 53: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 54: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 55: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 56: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 57: Lấy 100 orders, lọc được 0 orders trong khoảng thời gian
# Trang 58: Lấy 24 orders, lọc được 0 orders trong khoảng thời gian
# Tổng cộng lấy được 110 orders trong khoảng thời gian 2025-10-14 đến 2025-10-15
#
# === DỮ LIỆU JSON THÔ ===
# Số lượng orders: 110
#
# ==================================================
# ORDER 1 - JSON ĐẦY ĐỦ:
# ==================================================
# {
#   "id": 5871,
#   "sale_order_no": "DH101020808",
#   "campaign_name": null,
#   "book_date": "2025-10-15T00:00:00.000+07:00",
#   "sale_order_amount": 270000.0,
#   "deadline_date": null,
#   "quote_name": null,
#   "status": "Đang thực hiện",
#   "exchange_rate": 1.0,
#   "sale_order_name": "Đơn hàng tặng cho Lê Đàm Huy trúng giải mini game",
#   "sale_order_date": "2025-10-15T00:00:00.000+07:00",
#   "account_name": "Lê Đàm Huy",
#   "contact_name": null,
#   "due_date": "2025-10-15T00:00:00.000+07:00",
#   "delivery_status": "Đã giao hàng",
#   "sale_order_type": "Bán mới",
#   "opportunity_name": null,
#   "revenue_status": "Từ chối ghi",
#   "currency_type": "VND",
#   "description": "Hàng tặng",
#   "balance_receipt_amount": 270000.0,
#   "pay_status": "Chưa thanh toán",
#   "invoiced_amount": 270000.0,
#   "total_receipted_amount": 0.0,
#   "is_invoiced": true,
#   "un_invoiced_amount": 0.0,
#   "paid_date": null,
#   "delivery_date": "2025-10-16T00:00:00.000+07:00",
#   "un_subcrible": null,
#   "billing_account": "Lê Đàm Huy",
#   "billing_country": "Việt Nam",
#   "billing_district": null,
#   "billing_street": "Tổ 2",
#   "billing_address": "Tổ 2, Phường Thục Phán ,Tỉnh Cao Bằng",
#   "billing_contact": null,
#   "billing_province": "Cao Bằng",
#   "billing_ward": "Phường Thục Phán",
#   "billing_code": "203",
#   "shipping_country": "Việt Nam",
#   "shipping_district": "Thành phố Cao Bằng",
#   "shipping_street": "tổ 2",
#   "shipping_address": "tổ 2, phường Sông Hiến, thành phố Cao Bằng ( chi cục Kiềm Lâm )",
#   "phone": "0912256452",
#   "shipping_province": "Cao Bằng",
#   "shipping_ward": "Phường Sông Hiến",
#   "shipping_code": "2030113",
#   "organization_unit_name": "Bộ phận Kinh doanh Performent",
#   "created_by": "Xuân Đào (XUANDAO) - CRM",
#   "modified_by": "SME",
#   "form_layout": "Mẫu tiêu chuẩn",
#   "owner_name": "Xuân Đào (XUANDAO)",
#   "created_date": "2025-10-15T13:40:53.000+07:00",
#   "modified_date": "2025-10-16T11:53:12.000+07:00",
#   "is_public": false,
#   "tag": null,
#   "total_summary": 270000.0,
#   "tax_summary": 20000.0,
#   "discount_summary": 0.0,
#   "to_currency_summary": 250000.0,
#   "shipping_amount_summary": 5.0,
#   "sale_order_process_cost": 0.0,
#   "recorded_sale_organization_unit_name": "Bộ phận Kinh doanh Performent",
#   "recorded_sale_users_name": "Xuân Đào (XUANDAO)",
#   "parent_name": null,
#   "is_parent_sale_order": null,
#   "liquidate_amount": 270000.0,
#   "invoice_date": null,
#   "to_currency_summary_oc": 250000.0,
#   "discount_summary_oc": 0.0,
#   "tax_summary_oc": 20000.0,
#   "total_summary_oc": 270000.0,
#   "liquidate_amount_oc": 270000.0,
#   "sale_order_amount_oc": 270000.0,
#   "total_receipted_amount_oc": 0.0,
#   "balance_receipt_amount_oc": 270000.0,
#   "invoiced_amount_oc": 270000.0,
#   "is_use_currency": true,
#   "discount_overall": null,
#   "discount_overall_oc": null,
#   "tax_overall": null,
#   "tax_overall_oc": null,
#   "total_overall": null,
#   "total_overall_oc": null,
#   "discount_percent_overall": null,
#   "tax_percent_overall": null,
#   "to_currency_after_discount_summary": 250000.0,
#   "to_currency_oc_after_discount_summary": 250000.0,
#   "shipping_contact_name": "Lê Đàm Huy",
#   "is_correct_route": null,
#   "is_visited": null,
#   "amount_summary": 5.0,
#   "usage_unit_amount_summary": 5.0,
#   "number_of_days_owed": 0,
#   "list_product_category": "BALLS",
#   "list_product": "BALLGEN2",
#   "approved_status": null,
#   "approver": null,
#   "approved_date": null,
#   "other_sys_order_code": null,
#   "is_sync_price_after_discount": false,
#   "related_users": null,
#   "promotion_applied": null,
#   "custom_field1Summary": 0.0,
#   "custom_field13": null,
#   "custom_field1": null,
#   "production_confirmation_status": "Chưa gửi",
#   "production_status": null,
#   "production_date": null,
#   "production_rejection_reason": null,
#   "produced_quantity_summary": 0.0,
#   "account_code": "KH20092228",
#   "contact_code": null,
#   "opportunity_code": null,
#   "quote_code": null,
#   "employee_code": "XUANDAO",
#   "is_deleted": false,
#   "sale_order_product_mappings": [
#     {
#       "id": 22059,
#       "to_currency_oc": 250000.0,
#       "discount_oc": 0.0,
#       "tax_oc": 20000.0,
#       "total_oc": 270000.0,
#       "product_code": "BALLGEN2",
#       "unit": "Bóng",
#       "price": 50000.0,
#       "amount": 5.0,
#       "to_currency": 250000.0,
#       "discount": 0.0,
#       "tax": 20000.0,
#       "total": 270000.0,
#       "tax_percent": "8%",
#       "discount_percent": 0.0,
#       "shipping_amount": 5.0,
#       "stock_name": "FCL_KHO_HN_SI",
#       "description": "F-Pro Performance Pickleball Gen2",
#       "price_after_tax": 0.0,
#       "sort_order": 1,
#       "usage_unit": "Bóng",
#       "ratio": 1.0,
#       "operator": "Nhân",
#       "usage_unit_amount": 5.0,
#       "usage_unit_price": 50000.0,
#       "batch_number": null,
#       "exist_amount": null,
#       "height": 0.0,
#       "width": 0.0,
#       "length": 0.0,
#       "radius": 0.0,
#       "mass": 0.0,
#       "price_after_discount": 50000.0,
#       "to_currency_oc_after_discount": 250000.0,
#       "to_currency_after_discount": 250000.0,
#       "promotion": null,
#       "description_product": "F-Pro Performance Pickleball Gen2",
#       "sale_order_product": "",
#       "quantity_ordered": null,
#       "is_promotion": false,
#       "expire_date": null,
#       "serial_number": null,
#       "custom_field1": 0.0,
#       "produced_quantity": 0.0
#     }
#   ]
# }
#
# ==================================================
# ORDER 2 - JSON ĐẦY ĐỦ:
# ==================================================
# {
#   "id": 5846,
#   "sale_order_no": "DH101020782",
#   "campaign_name": null,
#   "book_date": "2025-10-15T00:00:00.000+07:00",
#   "sale_order_amount": 20781370.0,
#   "deadline_date": null,
#   "quote_name": null,
#   "status": "Đã thực hiện",
#   "exchange_rate": 1.0,
#   "sale_order_name": "Đơn bán + đơn ctrinh cồng dồn tặng bóng DH101020655 - 10 c, DH101020713 - 1c, DH101020732 - 1c, DH101020691 - 1c, DH101020782 - 7c",
#   "sale_order_date": "2025-10-15T00:00:00.000+07:00",
#   "account_name": "Nguyễn Minh Hiếu",
#   "contact_name": null,
#   "due_date": "2025-10-15T00:00:00.000+07:00",
#   "delivery_status": "Đã giao hàng",
#   "sale_order_type": "Bán mới",
#   "opportunity_name": null,
#   "revenue_status": "Đã ghi",
#   "currency_type": "VND",
#   "description": null,
#   "balance_receipt_amount": 0.0,
#   "pay_status": "Đã thanh toán",
#   "invoiced_amount": 20781370.0,
#   "total_receipted_amount": 20781370.0,
#   "is_invoiced": true,
#   "un_invoiced_amount": 0.0,
#   "paid_date": "2025-10-15T00:00:00.000+07:00",
#   "delivery_date": "2025-10-16T00:00:00.000+07:00",
#   "un_subcrible": false,
#   "billing_account": "Nguyễn Minh Hiếu",
#   "billing_country": "Việt Nam",
#   "billing_district": null,
#   "billing_street": "332 khu 1, ấp phước hội",
#   "billing_address": " khu 1, ấp phước hội, phường long hưng,  đồng nai",
#   "billing_contact": null,
#   "billing_province": "Đồng Nai",
#   "billing_ward": "Phường Long Hưng",
#   "billing_code": null,
#   "shipping_country": "Việt Nam",
#   "shipping_district": "Quận Bình Thạnh",
#   "shipping_street": "132/101b Nguyễn Hữu Cảng",
#   "shipping_address": "132/101b Nguyễn Hữu Cảng p22 quận bình thạnh",
#   "phone": "0373998782",
#   "shipping_province": "Hồ Chí Minh",
#   "shipping_ward": "Phường 22",
#   "shipping_code": null,
#   "organization_unit_name": "Bộ phận Kinh doanh Miền Nam",
#   "created_by": "Lê Anh Tuấn (NV11) - CRM",
#   "modified_by": "SME",
#   "form_layout": "Mẫu tiêu chuẩn",
#   "owner_name": "Lê Anh Tuấn (NV11)",
#   "created_date": "2025-10-15T10:35:15.000+07:00",
#   "modified_date": "2025-10-16T11:52:20.000+07:00",
#   "is_public": false,
#   "tag": null,
#   "total_summary": 20781370.0,
#   "tax_summary": 1539360.76,
#   "discount_summary": 17225583.331,
#   "to_currency_summary": 36467592.58,
#   "shipping_amount_summary": 12.0,
#   "sale_order_process_cost": 0.0,
#   "recorded_sale_organization_unit_name": "Bộ phận Kinh doanh Miền Nam",
#   "recorded_sale_users_name": "Lê Anh Tuấn (NV11)",
#   "parent_name": null,
#   "is_parent_sale_order": false,
#   "liquidate_amount": 20781370.0,
#   "invoice_date": null,
#   "to_currency_summary_oc": 36467592.58,
#   "discount_summary_oc": 17225583.331,
#   "tax_summary_oc": 1539360.76,
#   "total_summary_oc": 20781370.0,
#   "liquidate_amount_oc": 20781370.0,
#   "sale_order_amount_oc": 20781370.0,
#   "total_receipted_amount_oc": 20781370.0,
#   "balance_receipt_amount_oc": 0.0,
#   "invoiced_amount_oc": 20781370.0,
#   "is_use_currency": false,
#   "discount_overall": null,
#   "discount_overall_oc": null,
#   "tax_overall": null,
#   "tax_overall_oc": null,
#   "total_overall": null,
#   "total_overall_oc": null,
#   "discount_percent_overall": null,
#   "tax_percent_overall": null,
#   "to_currency_after_discount_summary": 19242009.24,
#   "to_currency_oc_after_discount_summary": 19242009.24,
#   "shipping_contact_name": "Nguyễn Minh Hiếu",
#   "is_correct_route": false,
#   "is_visited": false,
#   "amount_summary": 12.0,
#   "usage_unit_amount_summary": 12.0,
#   "number_of_days_owed": 0,
#   "list_product_category": "ACCESSORY,PRO,SPORT",
#   "list_product": "BACKPACK-ELITE-BLUE,BACKPACK-ELITE-NEON,BACKPACK-ELITE-PINK,BACKPACK-ELITE-WHITE,PDSS-ColorFul-16MM-SKYCANDY,PPS-DSS-16MM-BO,PPS-DSS-16MM-DB,PPS-DSS-16MM-DP,PPS-DSS-16MM-SA",
#   "approved_status": "Đã duyệt",
#   "approver": "Nguyễn Cao Hiền Triết (NGUYENTRIET)",
#   "approved_date": "2025-10-15T14:05:17.000+07:00",
#   "other_sys_order_code": null,
#   "is_sync_price_after_discount": false,
#   "related_users": null,
#   "promotion_applied": "KM0000008",
#   "custom_field1Summary": 0.0,
#   "custom_field13": "Đã duyệt",
#   "custom_field1": null,
#   "production_confirmation_status": "Chưa gửi",
#   "production_status": null,
#   "production_date": null,
#   "production_rejection_reason": null,
#   "produced_quantity_summary": 0.0,
#   "account_code": "Npp16-2",
#   "contact_code": null,
#   "opportunity_code": null,
#   "quote_code": null,
#   "employee_code": "NV11",
#   "is_deleted": false,
#   "sale_order_product_mappings": [
#     {
#       "id": 21898,
#       "to_currency_oc": 6481481.48,
#       "discount_oc": 2916666.67,
#       "tax_oc": 285185.19,
#       "total_oc": 3850000.0,
#       "product_code": "BACKPACK-ELITE-NEON",
#       "unit": "Chiếc",
#       "price": 3240740.74,
#       "amount": 2.0,
#       "to_currency": 6481481.48,
#       "discount": 2916666.666,
#       "tax": 285185.19,
#       "total": 3850000.0,
#       "tax_percent": "8%",
#       "discount_percent": 45.0,
#       "shipping_amount": 2.0,
#       "stock_name": "FCL_KHO_HCM",
#       "description": "Backpack Elite Facolos - Neon",
#       "price_after_tax": 0.0,
#       "sort_order": 1,
#       "usage_unit": "Chiếc",
#       "ratio": 1.0,
#       "operator": "Nhân",
#       "usage_unit_amount": 2.0,
#       "usage_unit_price": 3240740.74,
#       "batch_number": null,
#       "exist_amount": 0.0,
#       "height": 0.0,
#       "width": 0.0,
#       "length": 0.0,
#       "radius": 0.0,
#       "mass": 0.0,
#       "price_after_discount": 1782407.41,
#       "to_currency_oc_after_discount": 3564814.81,
#       "to_currency_after_discount": 3564814.81,
#       "promotion": "KM0000008",
#       "description_product": "Balo FACOLOS - Neon Balo thể thao đựng vợt Pickleball, Blue, Phiên bản Elite, nhãn hiệu Facolos",
#       "sale_order_product": null,
#       "quantity_ordered": null,
#       "is_promotion": false,
#       "expire_date": null,
#       "serial_number": null,
#       "custom_field1": 0.0,
#       "produced_quantity": null
#     },
#     {
#       "id": 21899,
#       "to_currency_oc": 3240740.74,
#       "discount_oc": 1458333.33,
#       "tax_oc": 142592.59,
#       "total_oc": 1925000.0,
#       "product_code": "BACKPACK-ELITE-PINK",
#       "unit": "Chiếc",
#       "price": 3240740.74,
#       "amount": 1.0,
#       "to_currency": 3240740.74,
#       "discount": 1458333.333,
#       "tax": 142592.59,
#       "total": 1925000.0,
#       "tax_percent": "8%",
#       "discount_percent": 45.0,
#       "shipping_amount": 1.0,
#       "stock_name": "FCL_KHO_HCM",
#       "description": "Backpack Elite Facolos - Pink",
#       "price_after_tax": 0.0,
#       "sort_order": 2,
#       "usage_unit": "Chiếc",
#       "ratio": 1.0,
#       "operator": "Nhân",
#       "usage_unit_amount": 1.0,
#       "usage_unit_price": 3240740.74,
#       "batch_number": null,
#       "exist_amount": 0.0,
#       "height": 0.0,
#       "width": 0.0,
#       "length": 0.0,
#       "radius": 0.0,
#       "mass": 0.0,
#       "price_after_discount": 1782407.41,
#       "to_currency_oc_after_discount": 1782407.41,
#       "to_currency_after_discount": 1782407.41,
#       "promotion": "KM0000008",
#       "description_product": "Balo FACOLOS - Pink",
#       "sale_order_product": null,
#       "quantity_ordered": null,
#       "is_promotion": false,
#       "expire_date": null,
#       "serial_number": null,
#       "custom_field1": 0.0,
#       "produced_quantity": null
#     },
#     {
#       "id": 21900,
#       "to_currency_oc": 6481481.48,
#       "discount_oc": 2916666.67,
#       "tax_oc": 285185.19,
#       "total_oc": 3850000.0,
#       "product_code": "BACKPACK-ELITE-BLUE",
#       "unit": "Chiếc",
#       "price": 3240740.74,
#       "amount": 2.0,
#       "to_currency": 6481481.48,
#       "discount": 2916666.666,
#       "tax": 285185.19,
#       "total": 3850000.0,
#       "tax_percent": "8%",
#       "discount_percent": 45.0,
#       "shipping_amount": 2.0,
#       "stock_name": "FCL_KHO_HCM",
#       "description": "Backpack Elite Facolos - Blue",
#       "price_after_tax": 0.0,
#       "sort_order": 3,
#       "usage_unit": "Chiếc",
#       "ratio": 1.0,
#       "operator": "Nhân",
#       "usage_unit_amount": 2.0,
#       "usage_unit_price": 3240740.74,
#       "batch_number": null,
#       "exist_amount": 0.0,
#       "height": 0.0,
#       "width": 0.0,
#       "length": 0.0,
#       "radius": 0.0,
#       "mass": 0.0,
#       "price_after_discount": 1782407.41,
#       "to_currency_oc_after_discount": 3564814.81,
#       "to_currency_after_discount": 3564814.81,
#       "promotion": "KM0000008",
#       "description_product": "Balo FACOLOS - Blue, Backpack Elite Facolos - Blue",
#       "sale_order_product": null,
#       "quantity_ordered": null,
#       "is_promotion": false,
#       "expire_date": null,
#       "serial_number": null,
#       "custom_field1": 0.0,
#       "produced_quantity": null
#     },
#     {
#       "id": 21901,
#       "to_currency_oc": 6481481.48,
#       "discount_oc": 2916666.67,
#       "tax_oc": 285185.19,
#       "total_oc": 3850000.0,
#       "product_code": "BACKPACK-ELITE-WHITE",
#       "unit": "Chiếc",
#       "price": 3240740.74,
#       "amount": 2.0,
#       "to_currency": 6481481.48,
#       "discount": 2916666.666,
#       "tax": 285185.19,
#       "total": 3850000.0,
#       "tax_percent": "8%",
#       "discount_percent": 45.0,
#       "shipping_amount": 2.0,
#       "stock_name": "FCL_KHO_HCM",
#       "description": "Backpack Elite Facolos - White",
#       "price_after_tax": 0.0,
#       "sort_order": 4,
#       "usage_unit": "Chiếc",
#       "ratio": 1.0,
#       "operator": "Nhân",
#       "usage_unit_amount": 2.0,
#       "usage_unit_price": 3240740.74,
#       "batch_number": null,
#       "exist_amount": 0.0,
#       "height": 0.0,
#       "width": 0.0,
#       "length": 0.0,
#       "radius": 0.0,
#       "mass": 0.0,
#       "price_after_discount": 1782407.41,
#       "to_currency_oc_after_discount": 3564814.81,
#       "to_currency_after_discount": 3564814.81,
#       "promotion": "KM0000008",
#       "description_product": "Balo FACOLOS - White",
#       "sale_order_product": null,
#       "quantity_ordered": null,
#       "is_promotion": false,
#       "expire_date": null,
#       "serial_number": null,
#       "custom_field1": 0.0,
#       "produced_quantity": null
#     },
#     {
#       "id": 22031,
#       "to_currency_oc": 3101851.85,
#       "discount_oc": 1599625.0,
#       "tax_oc": 120178.15,
#       "total_oc": 1622405.0,
#       "product_code": "PPS-DSS-16MM-DP",
#       "unit": "Chiếc",
#       "price": 3101851.85,
#       "amount": 1.0,
#       "to_currency": 3101851.85,
#       "discount": 1599625.0,
#       "tax": 120178.15,
#       "total": 1622405.0,
#       "tax_percent": "8%",
#       "discount_percent": 51.57,
#       "shipping_amount": 1.0,
#       "stock_name": "FCL_KHO_HCM",
#       "description": "Paddles Pro Series - Drive Swift Standard- 16MM - Dusty Pink",
#       "price_after_tax": 0.0,
#       "sort_order": 5,
#       "usage_unit": "Chiếc",
#       "ratio": 1.0,
#       "operator": "Nhân",
#       "usage_unit_amount": 1.0,
#       "usage_unit_price": 3101851.85,
#       "batch_number": null,
#       "exist_amount": 0.0,
#       "height": 0.0,
#       "width": 0.0,
#       "length": 0.0,
#       "radius": 0.0,
#       "mass": 0.0,
#       "price_after_discount": 1502226.85,
#       "to_currency_oc_after_discount": 1502226.85,
#       "to_currency_after_discount": 1502226.85,
#       "promotion": null,
#       "description_product": null,
#       "sale_order_product": null,
#       "quantity_ordered": null,
#       "is_promotion": false,
#       "expire_date": null,
#       "serial_number": null,
#       "custom_field1": 0.0,
#       "produced_quantity": null
#     },
#     {
#       "id": 22032,
#       "to_currency_oc": 3101851.85,
#       "discount_oc": 1599625.0,
#       "tax_oc": 120178.15,
#       "total_oc": 1622405.0,
#       "product_code": "PPS-DSS-16MM-BO",
#       "unit": "Chiếc",
#       "price": 3101851.85,
#       "amount": 1.0,
#       "to_currency": 3101851.85,
#       "discount": 1599625.0,
#       "tax": 120178.15,
#       "total": 1622405.0,
#       "tax_percent": "8%",
#       "discount_percent": 51.57,
#       "shipping_amount": 1.0,
#       "stock_name": "FCL_KHO_HCM",
#       "description": "Paddles Pro Series - Drive Swift Standard- 16MM - Burn Orange",
#       "price_after_tax": 0.0,
#       "sort_order": 6,
#       "usage_unit": "Chiếc",
#       "ratio": 1.0,
#       "operator": "Nhân",
#       "usage_unit_amount": 1.0,
#       "usage_unit_price": 3101851.85,
#       "batch_number": null,
#       "exist_amount": 0.0,
#       "height": 0.0,
#       "width": 0.0,
#       "length": 0.0,
#       "radius": 0.0,
#       "mass": 0.0,
#       "price_after_discount": 1502226.85,
#       "to_currency_oc_after_discount": 1502226.85,
#       "to_currency_after_discount": 1502226.85,
#       "promotion": null,
#       "description_product": null,
#       "sale_order_product": null,
#       "quantity_ordered": null,
#       "is_promotion": false,
#       "expire_date": null,
#       "serial_number": null,
#       "custom_field1": 0.0,
#       "produced_quantity": null
#     },
#     {
#       "id": 22054,
#       "to_currency_oc": 3101851.85,
#       "discount_oc": 1599625.0,
#       "tax_oc": 120178.15,
#       "total_oc": 1622405.0,
#       "product_code": "PPS-DSS-16MM-SA",
#       "unit": "Chiếc",
#       "price": 3101851.85,
#       "amount": 1.0,
#       "to_currency": 3101851.85,
#       "discount": 1599625.0,
#       "tax": 120178.15,
#       "total": 1622405.0,
#       "tax_percent": "8%",
#       "discount_percent": 51.57,
#       "shipping_amount": 1.0,
#       "stock_name": "FCL_KHO_HCM",
#       "description": "Paddles Pro Series - Drive Swift Standard- 16MM - Sand",
#       "price_after_tax": 0.0,
#       "sort_order": 7,
#       "usage_unit": "Chiếc",
#       "ratio": 1.0,
#       "operator": "Nhân",
#       "usage_unit_amount": 1.0,
#       "usage_unit_price": 3101851.85,
#       "batch_number": null,
#       "exist_amount": 0.0,
#       "height": 0.0,
#       "width": 0.0,
#       "length": 0.0,
#       "radius": 0.0,
#       "mass": 0.0,
#       "price_after_discount": 1502226.85,
#       "to_currency_oc_after_discount": 1502226.85,
#       "to_currency_after_discount": 1502226.85,
#       "promotion": null,
#       "description_product": null,
#       "sale_order_product": "-Không chọn-",
#       "quantity_ordered": null,
#       "is_promotion": false,
#       "expire_date": null,
#       "serial_number": null,
#       "custom_field1": 0.0,
#       "produced_quantity": null
#     },
#     {
#       "id": 22055,
#       "to_currency_oc": 3101851.85,
#       "discount_oc": 1599625.0,
#       "tax_oc": 120178.15,
#       "total_oc": 1622405.0,
#       "product_code": "PPS-DSS-16MM-DB",
#       "unit": "Chiếc",
#       "price": 3101851.85,
#       "amount": 1.0,
#       "to_currency": 3101851.85,
#       "discount": 1599625.0,
#       "tax": 120178.15,
#       "total": 1622405.0,
#       "tax_percent": "8%",
#       "discount_percent": 51.57,
#       "shipping_amount": 1.0,
#       "stock_name": "FCL_KHO_HCM",
#       "description": "Paddles Pro Series - Drive Swift Standard- 16MM - Dark Blue",
#       "price_after_tax": 0.0,
#       "sort_order": 8,
#       "usage_unit": "Chiếc",
#       "ratio": 1.0,
#       "operator": "Nhân",
#       "usage_unit_amount": 1.0,
#       "usage_unit_price": 3101851.85,
#       "batch_number": null,
#       "exist_amount": 0.0,
#       "height": 0.0,
#       "width": 0.0,
#       "length": 0.0,
#       "radius": 0.0,
#       "mass": 0.0,
#       "price_after_discount": 1502226.85,
#       "to_currency_oc_after_discount": 1502226.85,
#       "to_currency_after_discount": 1502226.85,
#       "promotion": null,
#       "description_product": null,
#       "sale_order_product": "-Không chọn-",
#       "quantity_ordered": null,
#       "is_promotion": false,
#       "expire_date": null,
#       "serial_number": null,
#       "custom_field1": 0.0,
#       "produced_quantity": null
#     },
#     {
#       "id": 22056,
#       "to_currency_oc": 1375000.0,
#       "discount_oc": 618750.0,
#       "tax_oc": 60500.0,
#       "total_oc": 816750.0,
#       "product_code": "PDSS-ColorFul-16MM-SKYCANDY",
#       "unit": "Chiếc",
#       "price": 1375000.0,
#       "amount": 1.0,
#       "to_currency": 1375000.0,
#       "discount": 618750.0,
#       "tax": 60500.0,
#       "total": 816750.0,
#       "tax_percent": "8%",
#       "discount_percent": 45.0,
#       "shipping_amount": 1.0,
#       "stock_name": "FCL_KHO_HCM",
#       "description": "Paddles Sport Series - ColorFul - 16MM - SkyCandy",
#       "price_after_tax": 0.0,
#       "sort_order": 9,
#       "usage_unit": "Chiếc",
#       "ratio": 1.0,
#       "operator": "Nhân",
#       "usage_unit_amount": 1.0,
#       "usage_unit_price": 1375000.0,
#       "batch_number": null,
#       "exist_amount": 0.0,
#       "height": 0.0,
#       "width": 0.0,
#       "length": 0.0,
#       "radius": 0.0,
#       "mass": 0.0,
#       "price_after_discount": 756250.0,
#       "to_currency_oc_after_discount": 756250.0,
#       "to_currency_after_discount": 756250.0,
#       "promotion": "KM0000008",
#       "description_product": null,
#       "sale_order_product": null,
#       "quantity_ordered": null,
#       "is_promotion": false,
#       "expire_date": null,
#       "serial_number": null,
#       "custom_field1": 0.0,
#       "produced_quantity": null
#     }
#   ]
# }
#
# ==================================================
# ORDER 3 - JSON ĐẦY ĐỦ:
# ==================================================
# {
#   "id": 5891,
#   "sale_order_no": "DH101020828",
#   "campaign_name": null,
#   "book_date": "2025-10-15T00:00:00.000+07:00",
#   "sale_order_amount": 3350000.0,
#   "deadline_date": null,
#   "quote_name": null,
#   "status": "Đang thực hiện",
#   "exchange_rate": 1.0,
#   "sale_order_name": "Đơn hàng tặng cho KOL/CELEB",
#   "sale_order_date": "2025-10-15T00:00:00.000+07:00",
#   "account_name": "Nguyễn Huỳnh Như",
#   "contact_name": null,
#   "due_date": "2025-10-15T00:00:00.000+07:00",
#   "delivery_status": "Đã giao hàng",
#   "sale_order_type": "Bán mới",
#   "opportunity_name": null,
#   "revenue_status": "Từ chối ghi",
#   "currency_type": "VND",
#   "description": "hàng tặng",
#   "balance_receipt_amount": 3350000.0,
#   "pay_status": "Chưa thanh toán",
#   "invoiced_amount": 3350000.0,
#   "total_receipted_amount": 0.0,
#   "is_invoiced": true,
#   "un_invoiced_amount": 0.0,
#   "paid_date": null,
#   "delivery_date": "2025-10-16T00:00:00.000+07:00",
#   "un_subcrible": null,
#   "billing_account": "Nguyễn Huỳnh Như",
#   "billing_country": "Việt Nam",
#   "billing_district": null,
#   "billing_street": "58/119 Đường Âu Cơ",
#   "billing_address": "58/119 Đường Âu Cơ, Phường Tân Hòa, Thành Phố Hồ Chí Minh",
#   "billing_contact": null,
#   "billing_province": "Hồ Chí Minh",
#   "billing_ward": "Phường Tân Hòa",
#   "billing_code": "701",
#   "shipping_country": "Việt Nam",
#   "shipping_district": null,
#   "shipping_street": "58/119 Đường Âu Cơ",
#   "shipping_address": "58/119 Đường Âu Cơ, Phường Tân Hòa, Thành Phố Hồ Chí Minh",
#   "phone": "0834898294",
#   "shipping_province": "Hồ Chí Minh",
#   "shipping_ward": "Phường Tân Hòa",
#   "shipping_code": "701",
#   "organization_unit_name": "Bộ phận Kinh doanh Performent",
#   "created_by": "Xuân Đào (XUANDAO) - CRM",
#   "modified_by": "SME",
#   "form_layout": "Mẫu tiêu chuẩn",
#   "owner_name": "Xuân Đào (XUANDAO)",
#   "created_date": "2025-10-15T16:58:15.000+07:00",
#   "modified_date": "2025-10-16T11:49:35.000+07:00",
#   "is_public": false,
#   "tag": null,
#   "total_summary": 3350000.0,
#   "tax_summary": 248148.15,
#   "discount_summary": 0.0,
#   "to_currency_summary": 3101851.85,
#   "shipping_amount_summary": 1.0,
#   "sale_order_process_cost": 0.0,
#   "recorded_sale_organization_unit_name": "Bộ phận Kinh doanh Performent",
#   "recorded_sale_users_name": "Xuân Đào (XUANDAO)",
#   "parent_name": null,
#   "is_parent_sale_order": null,
#   "liquidate_amount": 3350000.0,
#   "invoice_date": null,
#   "to_currency_summary_oc": 3101851.85,
#   "discount_summary_oc": 0.0,
#   "tax_summary_oc": 248148.15,
#   "total_summary_oc": 3350000.0,
#   "liquidate_amount_oc": 3350000.0,
#   "sale_order_amount_oc": 3350000.0,
#   "total_receipted_amount_oc": 0.0,
#   "balance_receipt_amount_oc": 3350000.0,
#   "invoiced_amount_oc": 3350000.0,
#   "is_use_currency": true,
#   "discount_overall": null,
#   "discount_overall_oc": null,
#   "tax_overall": null,
#   "tax_overall_oc": null,
#   "total_overall": null,
#   "total_overall_oc": null,
#   "discount_percent_overall": null,
#   "tax_percent_overall": null,
#   "to_currency_after_discount_summary": 3101851.85,
#   "to_currency_oc_after_discount_summary": 3101851.85,
#   "shipping_contact_name": "Nguyễn Huỳnh Như",
#   "is_correct_route": null,
#   "is_visited": null,
#   "amount_summary": 1.0,
#   "usage_unit_amount_summary": 1.0,
#   "number_of_days_owed": 0,
#   "list_product_category": "PRO",
#   "list_product": "PPS-DSS-16MM-DB",
#   "approved_status": null,
#   "approver": null,
#   "approved_date": null,
#   "other_sys_order_code": null,
#   "is_sync_price_after_discount": false,
#   "related_users": null,
#   "promotion_applied": null,
#   "custom_field1Summary": 0.0,
#   "custom_field13": null,
#   "custom_field1": null,
#   "production_confirmation_status": "Chưa gửi",
#   "production_status": null,
#   "production_date": null,
#   "production_rejection_reason": null,
#   "produced_quantity_summary": 0.0,
#   "account_code": "KH20092246",
#   "contact_code": null,
#   "opportunity_code": null,
#   "quote_code": null,
#   "employee_code": "XUANDAO",
#   "is_deleted": false,
#   "sale_order_product_mappings": [
#     {
#       "id": 22083,
#       "to_currency_oc": 3101851.85,
#       "discount_oc": 0.0,
#       "tax_oc": 248148.15,
#       "total_oc": 3350000.0,
#       "product_code": "PPS-DSS-16MM-DB",
#       "unit": "Chiếc",
#       "price": 3101851.85,
#       "amount": 1.0,
#       "to_currency": 3101851.85,
#       "discount": 0.0,
#       "tax": 248148.15,
#       "total": 3350000.0,
#       "tax_percent": "8%",
#       "discount_percent": 0.0,
#       "shipping_amount": 1.0,
#       "stock_name": "FCL_KHO_HCM",
#       "description": "Paddles Pro Series - Drive Swift Standard- 16MM - Dark Blue",
#       "price_after_tax": 0.0,
#       "sort_order": 1,
#       "usage_unit": "Chiếc",
#       "ratio": 1.0,
#       "operator": "Nhân",
#       "usage_unit_amount": 1.0,
#       "usage_unit_price": 3101851.85,
#       "batch_number": null,
#       "exist_amount": null,
#       "height": 0.0,
#       "width": 0.0,
#       "length": 0.0,
#       "radius": 0.0,
#       "mass": 0.0,
#       "price_after_discount": 3101851.85,
#       "to_currency_oc_after_discount": 3101851.85,
#       "to_currency_after_discount": 3101851.85,
#       "promotion": null,
#       "description_product": null,
#       "sale_order_product": "",
#       "quantity_ordered": null,
#       "is_promotion": false,
#       "expire_date": null,
#       "serial_number": null,
#       "custom_field1": 0.0,
#       "produced_quantity": 0.0
#     }
#   ]
# }
#
# ... và 107 orders khác
